# %% [markdown]
# # Setup (Imports)

# %%
import cython
import numpy as np
import time
import sph
# import main

# %% [markdown]
# # Original Program

# %% [markdown]
# ## Performance

# %%
import time
start = time.time()
sph.main()
elapsed = time.time() - start
print("Elapsed time: ", elapsed)
# Out:
# Elapsed time:  40.55983591079712

# %% [markdown]
# ##

# %% [markdown]
# ## Optimized Run

# %%
# import sph_parallel
import time
import subprocess
start = time.time()

# %%
! python sph_parallel.py
# Out:
# <multiprocessing.pool.Pool state=RUN pool_size=16>
# Figure(320x400)
# <multiprocessing.pool.Pool state=RUN pool_size=16>
# Figure(320x400)

# %%
elapsed = time.time() - start
print("Elapsed time: ", elapsed)
# Out:
# Elapsed time:  202.70504665374756

# %% [markdown]
# ## Performance Comparison
#
# Compilation overhead: 7.4 seconds
#
# ### N=400:
#
# Original program:  11.175616264343262
#
# Cython-optimized program: 7.52044153213501
#
# ### N=1000:
#
# Original program:  50.81005787849426
#
# Cython-optimized program: Elapsed time:  38.468353033065796
