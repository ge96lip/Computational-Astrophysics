# %% [markdown]
# ## Imports

# %%
import time
import subprocess
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# ## Function for measuring mean time and standard deviation of error

# %%
def run_experiment(script, N, extra_args=[], n_runs=5):
    times = []
    for _ in range(n_runs):
        start = time.time()
        cmd = ["python", script, str(N)] + [str(arg) for arg in extra_args]
        subprocess.run(cmd, stdout=subprocess.PIPE, stderr=subprocess.PIPE)
        times.append(time.time() - start)
    return np.mean(times), np.std(times, ddof=1) / np.sqrt(n_runs)

# %% [markdown]
# ## Variables

# %%
Ns = [100, 400, 600, 1000]
n_runs = 5
results = {}

# %% [markdown]
# ## Check for errors in Scripts

# %%
import subprocess

scripts = [
    (["python", "sph.py", "100"], "sph.py"),
    (["python", "sph_parallel.py", "100"], "sph_parallel.py"),
    (["python", "sph_parallel_shared_memory.py", "100"], "sph_parallel_shared_memory.py"),
    (["python", "sph_parallel_shared_memory_batched.py", "100", "100"], "sph_parallel_shared_memory_batched.py")
]

for cmd, name in scripts:
    try:
        result = subprocess.run(cmd, check=True, capture_output=True, text=True)
        print(f"{name} OK:\n{result.stdout}")
    except subprocess.CalledProcessError as e:
        print(f"{name} ERROR:\n{e.stderr}")
# Out:
# sph.py OK:
#
# sph_parallel.py OK:
# <multiprocessing.pool.Pool state=RUN pool_size=12>

# %% [markdown]
# # Measure Time

# %% [markdown]
# ## Original Code

# %%
sim = "sph"
results[sim] = {"Ns": [], "mean_times": [], "stderr": []}
for N in Ns:
    mean_time, stderr = run_experiment("sph.py", N, n_runs=n_runs)
    results[sim]["Ns"].append(N)
    results[sim]["mean_times"].append(mean_time)
    results[sim]["stderr"].append(stderr)
    print(f"{sim} with N={N}: {mean_time:.4f} ± {stderr:.4f}")
# Out:
# sph with N=1000: 1.0477 ± 0.1392
# sph with N=2000: 0.8421 ± 0.0077
# sph with N=5000: 0.8369 ± 0.0106
# sph with N=10000: 0.8494 ± 0.0093

# %% [markdown]
# ## Code with Mutliprocessing

# %%
sim = "sph_parallel"
results[sim] = {"Ns": [], "mean_times": [], "stderr": []}
for N in Ns:
    mean_time, stderr = run_experiment("sph_parallel.py", N, n_runs=n_runs)
    results[sim]["Ns"].append(N)
    results[sim]["mean_times"].append(mean_time)
    results[sim]["stderr"].append(stderr)
    print(f"{sim} with N={N}: {mean_time:.4f} ± {stderr:.4f}")
# Out:
# sph_parallel with N=1000: 0.9625 ± 0.0127
# sph_parallel with N=2000: 0.9670 ± 0.0259
# sph_parallel with N=5000: 0.9610 ± 0.0285
# sph_parallel with N=10000: 0.9452 ± 0.0162

# %% [markdown]
# ## Code with Multiprocessing and Shared Memory

# %%
sim = "sph_parallel_shared_memory"
results[sim] = {"Ns": [], "mean_times": [], "stderr": []}
for N in Ns:
    mean_time, stderr = run_experiment("sph_parallel_shared_memory.py", N, n_runs=n_runs)
    results[sim]["Ns"].append(N)
    results[sim]["mean_times"].append(mean_time)
    results[sim]["stderr"].append(stderr)
    print(f"{sim} with N={N}: {mean_time:.4f} ± {stderr:.4f}")
# Out:
# sph_parallel_shared_memory with N=1000: 0.9191 ± 0.0091
# sph_parallel_shared_memory with N=2000: 0.9608 ± 0.0255
# sph_parallel_shared_memory with N=5000: 0.9381 ± 0.0206
# sph_parallel_shared_memory with N=10000: 0.9620 ± 0.0122

# %% [markdown]
# ## Code with Multiprocessing, Shared Memory and Batches

# %%
batch_sizes = [1, 10, 50, 100, 500, 600, 700, 800, 900, 1000]
for batch in batch_sizes:
    sim = f"sph_parallel_shared_memory_batched (batch={batch})"
    results[sim] = {"Ns": [], "mean_times": [], "stderr": []}
    for N in Ns:
        mean_time, stderr = run_experiment("sph_parallel_shared_memory_batched.py", N, extra_args=[batch], n_runs=n_runs)
        results[sim]["Ns"].append(N)
        results[sim]["mean_times"].append(mean_time)
        results[sim]["stderr"].append(stderr)
        print(f"{sim} with N={N}: {mean_time:.4f} ± {stderr:.4f}")
# Out:
# sph_parallel_shared_memory_batched (batch=1) with N=1000: 0.9506 ± 0.0203
# sph_parallel_shared_memory_batched (batch=1) with N=2000: 0.9384 ± 0.0195
# sph_parallel_shared_memory_batched (batch=1) with N=5000: 0.9747 ± 0.0320
# sph_parallel_shared_memory_batched (batch=1) with N=10000: 0.9709 ± 0.0161
# sph_parallel_shared_memory_batched (batch=10) with N=1000: 1.0077 ± 0.0187
# sph_parallel_shared_memory_batched (batch=10) with N=2000: 0.9976 ± 0.0109
# sph_parallel_shared_memory_batched (batch=10) with N=5000: 0.9678 ± 0.0255
# sph_parallel_shared_memory_batched (batch=10) with N=10000: 0.9353 ± 0.0145
# sph_parallel_shared_memory_batched (batch=50) with N=1000: 0.9210 ± 0.0105
# sph_parallel_shared_memory_batched (batch=50) with N=2000: 0.9422 ± 0.0294
# sph_parallel_shared_memory_batched (batch=50) with N=5000: 0.9643 ± 0.0266
# sph_parallel_shared_memory_batched (batch=50) with N=10000: 1.0115 ± 0.0602
# sph_parallel_shared_memory_batched (batch=100) with N=1000: 0.9283 ± 0.0130
# sph_parallel_shared_memory_batched (batch=100) with N=2000: 0.9513 ± 0.0107
# sph_parallel_shared_memory_batched (batch=100) with N=5000: 0.9152 ± 0.0133
# sph_parallel_shared_memory_batched (batch=100) with N=10000: 0.9459 ± 0.0184
# sph_parallel_shared_memory_batched (batch=500) with N=1000: 0.9431 ± 0.0107
# sph_parallel_shared_memory_batched (batch=500) with N=2000: 0.9359 ± 0.0122
# sph_parallel_shared_memory_batched (batch=500) with N=5000: 0.9333 ± 0.0205
# sph_parallel_shared_memory_batched (batch=500) with N=10000: 0.9527 ± 0.0248
# sph_parallel_shared_memory_batched (batch=600) with N=1000: 0.9346 ± 0.0123
# sph_parallel_shared_memory_batched (batch=600) with N=2000: 0.9394 ± 0.0129
# sph_parallel_shared_memory_batched (batch=600) with N=5000: 0.9329 ± 0.0205
# sph_parallel_shared_memory_batched (batch=600) with N=10000: 0.9565 ± 0.0133
# sph_parallel_shared_memory_batched (batch=700) with N=1000: 0.9807 ± 0.0224
# sph_parallel_shared_memory_batched (batch=700) with N=2000: 0.9908 ± 0.0242
# sph_parallel_shared_memory_batched (batch=700) with N=5000: 1.0202 ± 0.0210
# sph_parallel_shared_memory_batched (batch=700) with N=10000: 1.0820 ± 0.0763
# sph_parallel_shared_memory_batched (batch=800) with N=1000: 0.9651 ± 0.0149
# sph_parallel_shared_memory_batched (batch=800) with N=2000: 0.9414 ± 0.0139
# sph_parallel_shared_memory_batched (batch=800) with N=5000: 0.9435 ± 0.0128
# sph_parallel_shared_memory_batched (batch=800) with N=10000: 0.9475 ± 0.0142
# sph_parallel_shared_memory_batched (batch=900) with N=1000: 0.9418 ± 0.0137
# sph_parallel_shared_memory_batched (batch=900) with N=2000: 0.9514 ± 0.0152
# sph_parallel_shared_memory_batched (batch=900) with N=5000: 0.9763 ± 0.0274
# sph_parallel_shared_memory_batched (batch=900) with N=10000: 0.9225 ± 0.0126
# sph_parallel_shared_memory_batched (batch=1000) with N=1000: 0.9619 ± 0.0169
# sph_parallel_shared_memory_batched (batch=1000) with N=2000: 0.9681 ± 0.0134
# sph_parallel_shared_memory_batched (batch=1000) with N=5000: 0.9230 ± 0.0121
# sph_parallel_shared_memory_batched (batch=1000) with N=10000: 0.9170 ± 0.0090

# %% [markdown]
# ## Plot Comparison Figure

# %%
plt.figure(figsize=(12, 8))
for sim, data in results.items():
    plt.errorbar(data["Ns"], data["mean_times"], yerr=data["stderr"],
                 marker='o', capsize=5, label=sim)
plt.xlabel("Number of Particles (N)")
plt.ylabel("Elapsed Time (s)")
plt.title("SPH Simulation Timing vs N")
plt.legend()
plt.grid(True)
plt.show()
