# %% [markdown]
# # Setup

# %% [markdown]
# ## Imports

# %%
import time
from timeit import default_timer as timer
import numpy as np
from functools import wraps
import cProfile
import subprocess
import matplotlib.pyplot as plt
from scipy.special import gamma
# from sph_profile import main as sph_run
NAME = ""

# %% [markdown]
# ## Functions from sph

# %%
def W( x, y, z, h ):
	"""
    Gausssian Smoothing kernel (3D)
	x     is a vector/matrix of x positions
	y     is a vector/matrix of y positions
	z     is a vector/matrix of z positions
	h     is the smoothing length
	w     is the evaluated smoothing function
	"""
	
	r = np.sqrt(x**2 + y**2 + z**2)
	
	w = (1.0 / (h*np.sqrt(np.pi)))**3 * np.exp( -r**2 / h**2)
	
	return w
	
	
def gradW( x, y, z, h ):
	"""
	Gradient of the Gausssian Smoothing kernel (3D)
	x     is a vector/matrix of x positions
	y     is a vector/matrix of y positions
	z     is a vector/matrix of z positions
	h     is the smoothing length
	wx, wy, wz     is the evaluated gradient
	"""
	
	r = np.sqrt(x**2 + y**2 + z**2)
	
	n = -2 * np.exp( -r**2 / h**2) / h**5 / (np.pi)**(3/2)
	wx = n * x
	wy = n * y
	wz = n * z
	
	return wx, wy, wz
	
	
def getPairwiseSeparations( ri, rj ):
	"""
	Get pairwise desprations between 2 sets of coordinates
	ri    is an M x 3 matrix of positions
	rj    is an N x 3 matrix of positions
	dx, dy, dz   are M x N matrices of separations
	"""
	
	M = ri.shape[0]
	N = rj.shape[0]
	
	# positions ri = (x,y,z)
	rix = ri[:,0].reshape((M,1))
	riy = ri[:,1].reshape((M,1))
	riz = ri[:,2].reshape((M,1))
	
	# other set of points positions rj = (x,y,z)
	rjx = rj[:,0].reshape((N,1))
	rjy = rj[:,1].reshape((N,1))
	rjz = rj[:,2].reshape((N,1))
	
	# matrices that store all pairwise particle separations: r_i - r_j
	dx = rix - rjx.T
	dy = riy - rjy.T
	dz = riz - rjz.T
	
	return dx, dy, dz
	

def getDensity( r, pos, m, h ):
	"""
	Get Density at sampling loctions from SPH particle distribution
	r     is an M x 3 matrix of sampling locations
	pos   is an N x 3 matrix of SPH particle positions
	m     is the particle mass
	h     is the smoothing length
	rho   is M x 1 vector of densities
	"""
	
	M = r.shape[0]
	
	dx, dy, dz = getPairwiseSeparations( r, pos );
	
	rho = np.sum( m * W(dx, dy, dz, h), 1 ).reshape((M,1))
	
	return rho
	
	
def getPressure(rho, k, n):
	"""
	Equation of State
	rho   vector of densities
	k     equation of state constant
	n     polytropic index
	P     pressure
	"""
	
	P = k * rho**(1+1/n)
	
	return P
	

def getAcc( pos, vel, m, h, k, n, lmbda, nu ):
	"""
	Calculate the acceleration on each SPH particle
	pos   is an N x 3 matrix of positions
	vel   is an N x 3 matrix of velocities
	m     is the particle mass
	h     is the smoothing length
	k     equation of state constant
	n     polytropic index
	lmbda external force constant
	nu    viscosity
	a     is N x 3 matrix of accelerations
	"""
	
	N = pos.shape[0]
	
	# Calculate densities at the position of the particles
	rho = getDensity( pos, pos, m, h )
	
	# Get the pressures
	P = getPressure(rho, k, n)
	
	# Get pairwise distances and gradients
	dx, dy, dz = getPairwiseSeparations( pos, pos )
	dWx, dWy, dWz = gradW( dx, dy, dz, h )
	
	# Add Pressure contribution to accelerations
	ax = - np.sum( m * ( P/rho**2 + P.T/rho.T**2  ) * dWx, 1).reshape((N,1))
	ay = - np.sum( m * ( P/rho**2 + P.T/rho.T**2  ) * dWy, 1).reshape((N,1))
	az = - np.sum( m * ( P/rho**2 + P.T/rho.T**2  ) * dWz, 1).reshape((N,1))
	
	# pack together the acceleration components
	a = np.hstack((ax,ay,az))
	
	# Add external potential force
	a -= lmbda * pos
	
	# Add viscosity
	a -= nu * vel
	
	return a

def main():
	""" SPH simulation """
	
	# Simulation parameters
	N         = 400    # Number of particles
	t         = 0      # current time of the simulation
	tEnd      = 12     # time at which simulation ends
	dt        = 0.04   # timestep
	M         = 2      # star mass
	R         = 0.75   # star radius
	h         = 0.1    # smoothing length
	k         = 0.1    # equation of state constant
	n         = 1      # polytropic index
	nu        = 1      # damping
	plotRealTime = False # switch on for plotting as the simulation goes along
	
	# Generate Initial Conditions
	np.random.seed(42)            # set the random number generator seed
	
	lmbda = 2*k*(1+n)*np.pi**(-3/(2*n)) * (M*gamma(5/2+n)/R**3/gamma(1+n))**(1/n) / R**2  # ~ 2.01
	m     = M/N                    # single particle mass
	pos   = np.random.randn(N,3)   # randomly selected positions and velocities
	vel   = np.zeros(pos.shape)
	
	# calculate initial gravitational accelerations
	acc = getAcc( pos, vel, m, h, k, n, lmbda, nu )
	
	# number of timesteps
	Nt = int(np.ceil(tEnd/dt))
	
	# prep figure
	fig = plt.figure(figsize=(4,5), dpi=80)
	grid = plt.GridSpec(3, 1, wspace=0.0, hspace=0.3)
	ax1 = plt.subplot(grid[0:2,0])
	ax2 = plt.subplot(grid[2,0])
	rr = np.zeros((100,3))
	rlin = np.linspace(0,1,100)
	rr[:,0] =rlin
	rho_analytic = lmbda/(4*k) * (R**2 - rlin**2)
	
	# Simulation Main Loop
	for i in range(Nt):
		# (1/2) kick
		vel += acc * dt/2
		
		# drift
		pos += vel * dt
		
		# update accelerations
		acc = getAcc( pos, vel, m, h, k, n, lmbda, nu )
		
		# (1/2) kick
		vel += acc * dt/2
		
		# update time
		t += dt
		
		# get density for plotting
		rho = getDensity( pos, pos, m, h )
		
		# plot in real time
		if plotRealTime or (i == Nt-1):
			plt.sca(ax1)
			plt.cla()
			cval = np.minimum((rho-3)/3,1).flatten()
			plt.scatter(pos[:,0],pos[:,1], c=cval, cmap=plt.cm.autumn, s=10, alpha=0.5)
			ax1.set(xlim=(-1.4, 1.4), ylim=(-1.2, 1.2))
			ax1.set_aspect('equal', 'box')
			ax1.set_xticks([-1,0,1])
			ax1.set_yticks([-1,0,1])
			ax1.set_facecolor('black')
			ax1.set_facecolor((.1,.1,.1))
			
			plt.sca(ax2)
			plt.cla()
			ax2.set(xlim=(0, 1), ylim=(0, 3))
			ax2.set_aspect(0.1)
			plt.plot(rlin, rho_analytic, color='gray', linewidth=2)
			rho_radial = getDensity( rr, pos, m, h )
			plt.plot(rlin, rho_radial, color='blue')
			plt.pause(0.001)
	    
	# add labels/legend
	plt.sca(ax2)
	plt.xlabel('radius')
	plt.ylabel('density')
	
	# Save figure
	# plt.savefig('sph.png',dpi=240)
	# plt.show()
	    
	return 0
	
	def sph():
		main()

# %% [markdown]
# ## CPU Profiler

# %%
import psutil
import time
import matplotlib.pyplot as plt
import pandas as pd
from functools import wraps

# Tool for recording CPU usage
class CPUProfiler:
    def __init__(self):
        self.data = []
        self.start_time = None

    def start(self):
        self.start_time = time.time()

    def record(self):
        if self.start_time is None:
            raise RuntimeError("Profiler has not been started.")
        elapsed_time = time.time() - self.start_time
        cpu_usage = psutil.cpu_percent(interval=1, percpu=True)
        self.data.append((elapsed_time, cpu_usage))

    def save_data(self, filename="cpu_usage.csv"):
        df = pd.DataFrame(self.data, columns=["Time (s)", "CPU Usage"])
        df.to_csv(filename, index=False)

    def plot(self):
        # Create a DataFrame for visualization
        times = [entry[0] for entry in self.data]
        usage = [entry[1] for entry in self.data]

        usage_transposed = list(zip(*usage))
        for core_idx, core_usage in enumerate(usage_transposed):
            plt.plot(times, core_usage, label=f"Core {core_idx}")
        
        plt.xlabel("Time (s)")
        plt.ylabel("CPU Usage (%)")
        plt.title("CPU Usage Per Core")
        plt.legend()
        plt.grid(True)
        plt.show()

    def summary_table(self):
        usage = [entry[1] for entry in self.data]
        avg_usage = [sum(core) / len(usage) for core in zip(*usage)]
        summary = pd.DataFrame({
            "Core": [f"Core {i}" for i in range(len(avg_usage))],
            "Average CPU Usage (%)": avg_usage
        })
        return summary

# Decorator to profile a function
def profile(func):
    @wraps(func)
    def wrapper(*args, **kwargs):
        profiler.record()  # Record before function call
        result = func(*args, **kwargs)
        profiler.record()  # Record after function call
        return result
    return wrapper

# Initialize profiler
profiler = CPUProfiler()

# Function implementations
grid_shape = (320, 320)

@profile
def evolve(grid, dt, D=1.0):
    xmax, ymax = grid_shape
    new_grid = [[0.0] * ymax for x in range(xmax)]
    for i in range(xmax):
        for j in range(ymax):
            grid_xx = (
                grid[(i + 1) % xmax][j] + grid[(i - 1) % xmax][j] - 2.0 * grid[i][j]
            )
            grid_yy = (
                grid[i][(j + 1) % ymax] + grid[i][(j - 1) % ymax] - 2.0 * grid[i][j]
            )
            new_grid[i][j] = grid[i][j] + D * (grid_xx + grid_yy) * dt
    return new_grid

def run_experiment(num_iterations):
    # Setting up initial conditions 
    xmax, ymax = grid_shape
    grid = [[0.0] * ymax for x in range(xmax)]

    # Simulating a drop of dye in the middle of our simulated region
    block_low = int(grid_shape[0] * 0.4)
    block_high = int(grid_shape[0] * 0.5)
    for i in range(block_low, block_high):
        for j in range(block_low, block_high):
            grid[i][j] = 0.005

    # Evolve the initial conditions
    for i in range(num_iterations):
        grid = evolve(grid, 0.1)

# %% [markdown]
# # Profiling

# %% [markdown]
# ## Profiling with cProfile

# %% [markdown]
# ### cProfile

# %%
! python -m cProfile -s cumulative sph.py
# Out:
# Figure(320x400)
#          1888531 function calls (1851619 primitive calls) in 12.859 seconds
#
#    Ordered by: cumulative time
#
#    ncalls  tottime  percall  cumtime  percall filename:lineno(function)
#    1030/1    0.016    0.000   12.861   12.861 {built-in method builtins.exec}
#         1    0.000    0.000   12.861   12.861 sph.py:1(<module>)
#         1    0.265    0.265   11.127   11.127 sph.py:155(main)
#       301    1.602    0.005    7.287    0.024 sph.py:111(getAcc)
#       127    0.006    0.000    6.118    0.048 __init__.py:1(<module>)
#       602    0.407    0.001    5.040    0.008 sph.py:78(getDensity)
#       602    3.626    0.006    3.626    0.006 sph.py:12(W)
#    1128/4    0.012    0.000    2.588    0.647 <frozen importlib._bootstrap>:1165(_find_and_load)
#    1122/4    0.008    0.000    2.588    0.647 <frozen importlib._bootstrap>:1120(_find_and_load_unlocked)
#    2559/9    0.003    0.000    2.583    0.287 <frozen importlib._bootstrap>:233(_call_with_frames_removed)
#    1087/6    0.006    0.000    2.582    0.430 <frozen importlib._bootstrap>:666(_load_unlocked)
#     993/6    0.005    0.000    2.582    0.430 <frozen importlib._bootstrap_external>:934(exec_module)
#       301    2.550    0.008    2.550    0.008 sph.py:29(gradW)
#    631/25    0.002    0.000    2.485    0.099 {built-in method builtins.__import__}
#  1204/114    0.004    0.000    2.277    0.020 <frozen importlib._bootstrap>:1207(_handle_fromlist)
#       903    1.348    0.001    1.351    0.001 sph.py:49(getPairwiseSeparations)
#      10/8    0.000    0.000    1.027    0.128 __init__.py:108(import_module)
#      11/8    0.000    0.000    1.027    0.128 <frozen importlib._bootstrap>:1192(_gcd_import)
#         4    0.000    0.000    0.856    0.214 pyplot.py:872(figure)
#         1    0.000    0.000    0.856    0.856 pyplot.py:549(new_figure_manager)
#         2    0.000    0.000    0.855    0.427 pyplot.py:526(_warn_if_gui_out_of_main_thread)
#         5    0.000    0.000    0.855    0.171 pyplot.py:359(_get_backend_mod)
#         1    0.000    0.000    0.855    0.855 pyplot.py:373(switch_backend)
#         1    0.000    0.000    0.854    0.854 registry.py:302(load_backend_module)
#         1    0.000    0.000    0.850    0.850 backend_inline.py:1(<module>)
#       993    0.017    0.000    0.803    0.001 <frozen importlib._bootstrap_external>:1007(get_code)
#         1    0.000    0.000    0.685    0.685 embed.py:1(<module>)
#         1    0.000    0.000    0.685    0.685 pyplot.py:1(<module>)
# 2834/2741    0.047    0.000    0.593    0.000 {built-in method builtins.__build_class__}
#         2    0.001    0.000    0.548    0.274 interactiveshell.py:1(<module>)
#       993    0.007    0.000    0.519    0.001 <frozen importlib._bootstrap_external>:1127(get_data)
#      1103    0.014    0.000    0.437    0.000 <frozen importlib._bootstrap>:1054(_find_spec)
#      1082    0.002    0.000    0.408    0.000 <frozen importlib._bootstrap_external>:1496(find_spec)
#      1082    0.007    0.000    0.406    0.000 <frozen importlib._bootstrap_external>:1464(_get_spec)
#       993    0.383    0.000    0.383    0.000 {built-in method io.open_code}
# 24864/23540    0.011    0.000    0.376    0.000 {built-in method builtins.hasattr}
#      1564    0.022    0.000    0.370    0.000 <frozen importlib._bootstrap_external>:1604(find_spec)
#         3    0.000    0.000    0.357    0.119 application.py:1(<module>)
#       106    0.001    0.000    0.352    0.003 artist.py:158(_update_set_signature_and_docstring)
#       105    0.001    0.000    0.347    0.003 artist.py:125(__init_subclass__)
#         1    0.000    0.000    0.332    0.332 figure.py:1(<module>)
#      4126    0.004    0.000    0.317    0.000 <frozen importlib._bootstrap_external>:140(_path_stat)
#      4172    0.316    0.000    0.316    0.000 {built-in method nt.stat}
#         1    0.000    0.000    0.280    0.280 colorbar.py:1(<module>)
#       120    0.001    0.000    0.272    0.002 artist.py:1832(kwdoc)
#      1505    0.012    0.000    0.242    0.000 fromnumeric.py:2349(sum)
#       120    0.006    0.000    0.234    0.002 artist.py:1593(pprint_setters)
#      1695    0.016    0.000    0.228    0.000 fromnumeric.py:69(_wrapreduction)
#         1    0.000    0.000    0.215    0.215 _support_alternative_backends.py:1(<module>)
#         1    0.000    0.000    0.213    0.213 _array_api.py:1(<module>)
#      2109    0.208    0.000    0.208    0.000 {method 'reduce' of 'numpy.ufunc' objects}
#         2    0.000    0.000    0.202    0.101 debugger.py:1(<module>)
#        10    0.000    0.000    0.201    0.020 __init__.py:340(__getattr__)
#      4409    0.017    0.000    0.194    0.000 artist.py:1461(get_valid_values)
#         1    0.000    0.000    0.185    0.185 contour.py:1(<module>)
#         1    0.000    0.000    0.175    0.175 backend_bases.py:1(<module>)
#       993    0.005    0.000    0.166    0.000 <frozen importlib._bootstrap_external>:727(_compile_bytecode)
#         1    0.000    0.000    0.164    0.164 completer.py:1(<module>)
#      7785    0.010    0.000    0.164    0.000 __init__.py:272(_compile)
#         1    0.000    0.000    0.164    0.164 _orthogonal.py:1(<module>)
#       3/1    0.000    0.000    0.163    0.163 __init__.py:145(__getattr__)
#       993    0.159    0.000    0.159    0.000 {built-in method marshal.loads}
#         3    0.000    0.000    0.152    0.051 text.py:1(<module>)
# 1087/1072    0.003    0.000    0.150    0.000 <frozen importlib._bootstrap>:566(module_from_spec)
#         1    0.000    0.000    0.150    0.150 rcsetup.py:1(<module>)
#      7558    0.095    0.000    0.149    0.000 inspect.py:867(cleandoc)
#       406    0.003    0.000    0.147    0.000 _compiler.py:738(compile)
#       980    0.001    0.000    0.142    0.000 __init__.py:748(__setitem__)
#         1    0.000    0.000    0.134    0.134 buffer.py:1(<module>)
#      7516    0.008    0.000    0.129    0.000 inspect.py:848(getdoc)
#         1    0.000    0.000    0.122    0.122 _axes.py:1(<module>)
#       366    0.000    0.000    0.115    0.000 __init__.py:225(compile)
#        12    0.000    0.000    0.107    0.009 base.py:1(<module>)
#         3    0.000    0.000    0.107    0.036 rcsetup.py:272(validate_backend)
#         1    0.000    0.000    0.107    0.107 _sketches.py:1(<module>)
#         3    0.000    0.000    0.107    0.036 registry.py:202(is_valid_backend)
#         1    0.000    0.000    0.107    0.107 registry.py:113(_ensure_entry_points_loaded)
#         1    0.000    0.000    0.107    0.107 registry.py:128(_read_entry_points)
#         2    0.000    0.000    0.106    0.053 __config__.py:1(<module>)
#         1    0.000    0.000    0.103    0.103 pyplot.py:735(pause)
#       993    0.102    0.000    0.102    0.000 {method 'read' of '_io.BufferedReader' objects}
#      1449    0.002    0.000    0.101    0.000 <frozen importlib._bootstrap_external>:150(_path_is_mode_type)
#         1    0.000    0.000    0.101    0.101 crashhandler.py:1(<module>)
#         1    0.000    0.000    0.098    0.098 ultratb.py:1(<module>)
#     70/69    0.000    0.000    0.095    0.001 <frozen importlib._bootstrap_external>:1231(create_module)
#      1327    0.001    0.000    0.095    0.000 <frozen importlib._bootstrap_external>:159(_path_isfile)
#     70/69    0.075    0.001    0.095    0.001 {built-in method _imp.create_dynamic}
#         1    0.000    0.000    0.092    0.092 backend_bases.py:1876(draw_idle)
#         1    0.000    0.000    0.092    0.092 backend_agg.py:375(draw)
#      7695    0.062    0.000    0.092    0.000 <frozen importlib._bootstrap_external>:96(_path_join)
#         1    0.000    0.000    0.092    0.092 artist.py:92(draw_wrapper)
#     140/1    0.001    0.000    0.092    0.092 artist.py:53(draw_wrapper)
#         1    0.000    0.000    0.092    0.092 figure.py:3237(draw)
#       406    0.002    0.000    0.091    0.000 _parser.py:970(parse)
#       227    0.001    0.000    0.090    0.000 artist.py:1413(__init__)
#         1    0.000    0.000    0.090    0.090 f2py2e.py:1(<module>)
#         5    0.001    0.000    0.090    0.018 core.py:1(<module>)
#       3/1    0.000    0.000    0.090    0.090 image.py:116(_draw_list_compositing_images)
#         2    0.000    0.000    0.090    0.045 _base.py:3116(draw)
#       227    0.015    0.000    0.089    0.000 artist.py:1433(get_aliases)
#  1181/406    0.005    0.000    0.087    0.000 _parser.py:447(_parse_sub)
#  1474/448    0.033    0.000    0.084    0.000 _parser.py:507(_parse)
#         1    0.000    0.000    0.080    0.080 collections.py:1(<module>)
#         1    0.000    0.000    0.080    0.080 colors.py:1(<module>)
#         4    0.000    0.000    0.079    0.020 axis.py:1407(draw)
#         3    0.000    0.000    0.076    0.025 _base.py:1(<module>)
#         1    0.000    0.000    0.076    0.076 classes.py:1(<module>)
#         1    0.000    0.000    0.070    0.070 ipapp.py:1(<module>)
#         1    0.000    0.000    0.067    0.067 crackfortran.py:1(<module>)
#         1    0.000    0.000    0.066    0.066 patches.py:1(<module>)
#       993    0.002    0.000    0.065    0.000 <frozen importlib._bootstrap_external>:1146(path_stats)
#         1    0.000    0.000    0.065    0.065 axes3d.py:1(<module>)
#     40/28    0.000    0.000    0.065    0.002 axis.py:1596(_get_tick)
#         1    0.000    0.000    0.061    0.061 async_helpers.py:1(<module>)
#        15    0.001    0.000    0.061    0.004 utils.py:1(<module>)
#         4    0.000    0.000    0.060    0.015 _base.py:1409(clear)
#         4    0.000    0.000    0.060    0.015 _base.py:1277(__clear)
#      5938    0.005    0.000    0.058    0.000 __init__.py:173(search)
#         1    0.000    0.000    0.057    0.057 _fontconfig_pattern.py:1(<module>)
#       227    0.020    0.000    0.057    0.000 artist.py:1511(get_setters)
#         1    0.000    0.000    0.057    0.057 imports.py:1(<module>)
#        31    0.008    0.000    0.053    0.002 __init__.py:884(_rc_params_in_file)
#         1    0.000    0.000    0.052    0.052 _laplacian.py:1(<module>)
#         9    0.000    0.000    0.052    0.006 _base.py:747(__init_subclass__)
#       406    0.001    0.000    0.052    0.000 _compiler.py:571(_code)
#      1986    0.011    0.000    0.052    0.000 <frozen importlib._bootstrap_external>:437(cache_from_source)
#     20/16    0.000    0.000    0.052    0.003 axis.py:1126(set_clip_path)
#         3    0.000    0.000    0.051    0.017 auto_suggest.py:1(<module>)
#      4930    0.003    0.000    0.051    0.000 {built-in method builtins.sorted}
#      1087    0.007    0.000    0.051    0.000 <frozen importlib._bootstrap>:493(_init_module_attrs)
#         1    0.000    0.000    0.050    0.050 magic.py:1(<module>)
#        14    0.000    0.000    0.049    0.004 axis.py:1655(get_major_ticks)
#         1    0.000    0.000    0.048    0.048 __init__.py:1020(entry_points)
#         1    0.000    0.000    0.047    0.047 ansi.py:1(<module>)
#         1    0.000    0.000    0.047    0.047 __init__.py:473(load)
#       148    0.000    0.000    0.047    0.000 __init__.py:1037(<genexpr>)
#         1    0.000    0.000    0.047    0.047 _index_tricks_impl.py:1(<module>)
#         4    0.000    0.000    0.046    0.012 defaults.py:1(<module>)
#         1    0.000    0.000    0.045    0.045 document.py:1(<module>)
#     28/20    0.000    0.000    0.044    0.002 axis.py:534(__get__)
#        40    0.002    0.000    0.044    0.001 axis.py:59(__init__)
#         1    0.000    0.000    0.043    0.043 oinspect.py:1(<module>)
#       817    0.001    0.000    0.042    0.000 inspect.py:3278(signature)
#   128/117    0.001    0.000    0.042    0.000 _docstring.py:122(__call__)
#       817    0.001    0.000    0.042    0.000 inspect.py:3024(from_callable)
#     24/20    0.001    0.000    0.041    0.002 axis.py:899(reset_ticks)
#   894/818    0.006    0.000    0.041    0.000 inspect.py:2428(_signature_from_callable)
#        12    0.001    0.000    0.041    0.003 axis.py:1287(_update_ticks)
#         1    0.000    0.000    0.040    0.040 Image.py:1(<module>)
#  2838/406    0.019    0.000    0.040    0.000 _compiler.py:37(_compile)
#         1    0.000    0.000    0.039    0.039 defmatrix.py:1(<module>)
#         1    0.000    0.000    0.038    0.038 font_manager.py:1(<module>)
#         2    0.000    0.000    0.038    0.019 pyplot.py:1381(subplot)
#         2    0.000    0.000    0.038    0.019 figure.py:644(add_subplot)
#         2    0.000    0.000    0.037    0.019 _base.py:579(__init__)
#         1    0.000    0.000    0.037    0.037 base_events.py:1(<module>)
# 107075/107045    0.033    0.000    0.036    0.000 {built-in method builtins.getattr}
#   913/810    0.002    0.000    0.036    0.000 typing.py:349(inner)
#         8    0.000    0.000    0.035    0.004 axis.py:856(clear)
#        14    0.000    0.000    0.035    0.002 _docstring.py:73(__missing__)
#      2056    0.002    0.000    0.035    0.000 <frozen importlib._bootstrap>:392(cached)
#     21/15    0.000    0.000    0.035    0.002 axis.py:367(__init__)
#         2    0.000    0.000    0.034    0.017 _linalg.py:1(<module>)
#         4    0.000    0.000    0.034    0.008 basic.py:1(<module>)
#      1063    0.002    0.000    0.033    0.000 <frozen importlib._bootstrap_external>:567(_get_cached)
#        91    0.000    0.000    0.033    0.000 traitlets.py:972(__init__)
#        90    0.007    0.000    0.032    0.000 traitlets.py:999(setup_class)
#     70/62    0.000    0.000    0.032    0.001 <frozen importlib._bootstrap_external>:1239(exec_module)
#         2    0.000    0.000    0.032    0.016 pyplot.py:1373(cla)
#     70/62    0.013    0.000    0.032    0.001 {built-in method _imp.exec_dynamic}
#         2    0.000    0.000    0.032    0.016 _base.py:1418(cla)
#         1    0.000    0.000    0.031    0.031 art3d.py:1(<module>)
#         1    0.028    0.028    0.031    0.031 app.py:1(<module>)
#       227    0.018    0.000    0.031    0.000 artist.py:1444(<listcomp>)
#         2    0.000    0.000    0.031    0.015 _adapters.py:1(<module>)
#    139678    0.023    0.000    0.030    0.000 {built-in method builtins.isinstance}
#     19/13    0.000    0.000    0.030    0.002 axis.py:428(__init__)
#       784    0.010    0.000    0.029    0.000 inspect.py:2333(_signature_from_function)
#         1    0.000    0.000    0.029    0.029 _axes.py:67(Axes)
#      1072    0.028    0.000    0.028    0.000 {method '__exit__' of '_io._IOBase' objects}
#       147    0.000    0.000    0.028    0.000 __init__.py:634(entry_points)
#      1694    0.002    0.000    0.028    0.000 <frozen importlib._bootstrap_external>:1421(_path_importer_cache)
#         1    0.000    0.000    0.027    0.027 named_commands.py:1(<module>)
#         1    0.000    0.000    0.027    0.027 message.py:1(<module>)
#         1    0.000    0.000    0.027    0.027 cm.py:1(<module>)
#         2    0.000    0.000    0.027    0.014 core.py:198(read_style_directory)
#       120    0.001    0.000    0.025    0.000 <frozen importlib._bootstrap_external>:1408(_path_hooks)
#       652    0.025    0.000    0.025    0.000 {built-in method builtins.dir}
# 5110/4328    0.011    0.000    0.025    0.000 {built-in method __new__ of type object at 0x00007FF95D628F90}
#       120    0.004    0.000    0.024    0.000 <frozen importlib._bootstrap_external>:1655(_fill_cache)
#         1    0.000    0.000    0.024    0.024 textpath.py:1(<module>)
#      7237    0.014    0.000    0.024    0.000 inspect.py:2686(__init__)
# 215652/212678    0.022    0.000    0.024    0.000 {built-in method builtins.len}
#         1    0.000    0.000    0.023    0.023 axis.py:1(<module>)
#   176/112    0.001    0.000    0.023    0.000 spines.py:340(get_spine_transform)
#   176/112    0.000    0.000    0.023    0.000 spines.py:203(_ensure_position_is_set)
#     16/12    0.000    0.000    0.023    0.002 spines.py:300(set_position)
#    122332    0.022    0.000    0.022    0.000 {method 'startswith' of 'str' objects}
#         1    0.000    0.000    0.022    0.022 geo.py:1(<module>)
#     10259    0.022    0.000    0.022    0.000 {method 'search' of 're.Pattern' objects}
#       148    0.001    0.000    0.022    0.000 __init__.py:930(read_text)
#         1    0.000    0.000    0.021    0.021 category.py:1(<module>)
#        87    0.002    0.000    0.021    0.000 enum.py:496(__new__)
#       608    0.005    0.000    0.021    0.000 artist.py:1188(_update_props)
#        12    0.000    0.000    0.021    0.002 _base.py:73(wrapper)
#         2    0.000    0.000    0.021    0.011 subprocess.py:506(run)
#         1    0.000    0.000    0.021    0.021 offsetbox.py:1(<module>)
#         1    0.000    0.000    0.021    0.021 multiarray.py:1(<module>)
#         2    0.000    0.000    0.021    0.010 axis.py:2183(set_ticks)
#         2    0.000    0.000    0.021    0.010 axis.py:2165(_set_tick_locations)
#         1    0.000    0.000    0.021    0.021 numeric.py:1(<module>)
#         3    0.000    0.000    0.021    0.007 parser.py:1(<module>)
#         2    0.000    0.000    0.020    0.010 code.py:1(<module>)
#         1    0.000    0.000    0.020    0.020 typeshed.py:1(<module>)
#       200    0.001    0.000    0.020    0.000 pyplot.py:176(_copy_docstring_and_deprecators)
#       134    0.020    0.000    0.020    0.000 {built-in method nt.listdir}
#       122    0.003    0.000    0.020    0.000 lines.py:287(__init__)
#         1    0.000    0.000    0.020    0.020 cursor_shapes.py:1(<module>)
#        16    0.000    0.000    0.020    0.001 axis.py:268(draw)
#         1    0.000    0.000    0.020    0.020 platform.py:951(machine)
#      1124    0.002    0.000    0.020    0.000 <frozen importlib._bootstrap>:169(__enter__)
#         1    0.000    0.000    0.020    0.020 value.py:1(<module>)
#         3    0.000    0.000    0.020    0.007 platform.py:825(uname)
#        91    0.004    0.000    0.020    0.000 traitlets.py:977(setup_class)
#         1    0.000    0.000    0.020    0.020 platform.py:363(win32_ver)
#       901    0.002    0.000    0.019    0.000 colors.py:277(to_rgba)
#       687    0.001    0.000    0.019    0.000 colors.py:223(is_color_like)
#         2    0.000    0.000    0.019    0.010 overrides.py:1(<module>)
#       456    0.001    0.000    0.019    0.000 artist.py:1530(number_of_parameters)
#         1    0.000    0.000    0.019    0.019 platform.py:263(_syscmd_ver)
#         1    0.000    0.000    0.019    0.019 stub_value.py:1(<module>)
#         1    0.000    0.000    0.019    0.019 subprocess.py:417(check_output)
#       148    0.000    0.000    0.019    0.000 _itertools.py:4(unique_everseen)
#       426    0.001    0.000    0.019    0.000 rcsetup.py:332(validate_color)
#         1    0.000    0.000    0.019    0.019 lines.py:1(<module>)
#       148    0.000    0.000    0.018    0.000 pathlib.py:1053(read_text)
#       506    0.000    0.000    0.018    0.000 artist.py:1226(_internal_update)
#         1    0.000    0.000    0.018    0.018 containers.py:1(<module>)
#       379    0.000    0.000    0.018    0.000 artist.py:146(<lambda>)
#         1    0.000    0.000    0.018    0.018 grammar.py:1(<module>)
#       379    0.001    0.000    0.018    0.000 artist.py:1237(set)
#         1    0.000    0.000    0.017    0.017 _parser.py:1(<module>)
#         1    0.000    0.000    0.017    0.017 polar.py:1(<module>)
#   250/207    0.000    0.000    0.017    0.000 typing.py:476(__getitem__)
#      1063    0.003    0.000    0.017    0.000 <frozen importlib._bootstrap_external>:1599(_get_spec)
#       187    0.015    0.000    0.016    0.000 {built-in method io.open}
#       984    0.001    0.000    0.016    0.000 artist.py:1536(is_alias)
#       190    0.001    0.000    0.016    0.000 colors.py:324(_to_rgba_no_colorcycle)
#       530    0.003    0.000    0.016    0.000 typing.py:1346(__init__)
#       303    0.012    0.000    0.016    0.000 {built-in method builtins.eval}
#         1    0.000    0.000    0.016    0.016 _afm.py:1(<module>)
#         1    0.000    0.000    0.016    0.016 rules.py:1(<module>)
#         8    0.000    0.000    0.016    0.002 axis.py:1339(_get_ticklabel_bboxes)
#       207    0.001    0.000    0.016    0.000 typing.py:653(Union)
#         8    0.000    0.000    0.015    0.002 axis.py:1343(<listcomp>)
#       100    0.000    0.000    0.015    0.000 text.py:104(__init__)
#        48    0.002    0.000    0.015    0.000 text.py:358(_get_layout)
#        32    0.001    0.000    0.015    0.000 text.py:926(get_window_extent)
#       103    0.001    0.000    0.015    0.000 artist.py:784(set_clip_path)
#      1870    0.008    0.000    0.015    0.000 <frozen importlib._bootstrap>:179(_get_module_lock)
#        94    0.001    0.000    0.015    0.000 __init__.py:1447(_preprocess_data)
#       100    0.001    0.000    0.015    0.000 pyplot.py:209(_add_pyplot_note)
#         1    0.000    0.000    0.015    0.015 shape_base.py:1(<module>)
#         1    0.000    0.000    0.015    0.015 _pickle.py:1(<module>)
#         4    0.000    0.000    0.015    0.004 display.py:1(<module>)
#         2    0.000    0.000    0.015    0.007 _internal.py:1(<module>)
#         1    0.000    0.000    0.015    0.015 request.py:1(<module>)
#       106    0.003    0.000    0.015    0.000 artist.py:169(<listcomp>)
#         3    0.000    0.000    0.015    0.005 history.py:1(<module>)
# 23460/23453    0.012    0.000    0.014    0.000 {method 'join' of 'str' objects}
#         1    0.000    0.000    0.014    0.014 image.py:1(<module>)
#         2    0.000    0.000    0.014    0.007 filters.py:1(<module>)
#         3    0.000    0.000    0.014    0.005 common.py:1(<module>)
#       780    0.009    0.000    0.013    0.000 enum.py:241(__set_name__)
#         1    0.000    0.000    0.013    0.013 _mathtext_data.py:1(<module>)
#     13639    0.007    0.000    0.013    0.000 _parser.py:252(get)
#         2    0.000    0.000    0.013    0.007 ElementTree.py:1(<module>)
#     67743    0.013    0.000    0.013    0.000 {built-in method builtins.min}
#     154/1    0.013    0.000    0.013    0.013 _mathtext_data.py:1722(_normalize_stix_fontcodes)
#       4/1    0.000    0.000    0.013    0.013 _mathtext_data.py:1728(<dictcomp>)
#      8761    0.006    0.000    0.013    0.000 enum.py:685(__call__)
#        12    0.000    0.000    0.013    0.001 _mathtext_data.py:1726(<listcomp>)
#        91    0.005    0.000    0.013    0.000 traitlets.py:276(getmembers)
#        11    0.000    0.000    0.013    0.001 magic_arguments.py:233(__call__)
#       120    0.001    0.000    0.013    0.000 <frozen zipimport>:64(__init__)
#        11    0.000    0.000    0.013    0.001 magic_arguments.py:171(construct_parser)
#        46    0.001    0.000    0.013    0.000 text.py:738(draw)
#        48    0.012    0.000    0.013    0.000 {method 'read' of '_io.TextIOWrapper' objects}
#      1063    0.005    0.000    0.013    0.000 <frozen importlib._bootstrap_external>:778(spec_from_file_location)
#       148    0.000    0.000    0.013    0.000 pathlib.py:1036(open)
#         1    0.000    0.000    0.013    0.013 page.py:1(<module>)
#        81    0.005    0.000    0.013    0.000 __init__.py:348(namedtuple)
#      4409    0.006    0.000    0.013    0.000 artist.py:1549(aliased_name)
#         1    0.000    0.000    0.013    0.013 __init__.py:245(_check_versions)
#         1    0.000    0.000    0.012    0.012 fromnumeric.py:1(<module>)
#         1    0.000    0.000    0.012    0.012 api.py:1(<module>)
#      1986    0.005    0.000    0.012    0.000 <frozen importlib._bootstrap_external>:132(_path_split)
#         8    0.000    0.000    0.012    0.002 axis.py:761(_set_scale)
#         1    0.000    0.000    0.012    0.012 pathlib.py:1(<module>)
#     91451    0.012    0.000    0.012    0.000 {method 'append' of 'list' objects}
#      1125    0.009    0.000    0.012    0.000 inspect.py:2972(__init__)
#       301    0.008    0.000    0.012    0.000 shape_base.py:294(hstack)
#         8    0.000    0.000    0.012    0.002 scale.py:103(set_default_locators_and_formatters)
#         1    0.000    0.000    0.012    0.012 PngImagePlugin.py:1(<module>)
#       239    0.000    0.000    0.012    0.000 markers.py:220(__init__)
#        30    0.000    0.000    0.012    0.000 __init__.py:914(<genexpr>)
#     89805    0.012    0.000    0.012    0.000 {method 'lstrip' of 'str' objects}
# 2047/1983    0.001    0.000    0.012    0.000 {built-in method builtins.next}
#         2    0.000    0.000    0.012    0.006 subprocess.py:807(__init__)
#        27    0.000    0.000    0.012    0.000 __init__.py:812(search)
#         1    0.000    0.000    0.012    0.012 npyio.py:1(<module>)
#    197/75    0.000    0.000    0.012    0.000 _base.py:928(get_xaxis_transform)
#     20575    0.009    0.000    0.012    0.000 _parser.py:162(__getitem__)
#    179/65    0.000    0.000    0.012    0.000 _base.py:1010(get_yaxis_transform)
#         1    0.000    0.000    0.011    0.011 quiver.py:1(<module>)
#         1    0.000    0.000    0.011    0.011 colorizer.py:1(<module>)
#         1    0.000    0.000    0.011    0.011 cd.py:1(<module>)
#       120    0.001    0.000    0.011    0.000 <frozen importlib._bootstrap_external>:1696(path_hook_for_FileFinder)
#        40    0.000    0.000    0.011    0.000 axis.py:234(set_clip_path)
#         3    0.000    0.000    0.011    0.004 config.py:1(<module>)
#         1    0.000    0.000    0.011    0.011 axis3d.py:1(<module>)
#         2    0.000    0.000    0.011    0.006 subprocess.py:1436(_execute_child)
#       239    0.001    0.000    0.011    0.000 markers.py:299(_set_marker)
#       118    0.000    0.000    0.011    0.000 patches.py:307(get_transform)
#         1    0.000    0.000    0.011    0.011 _npyio_impl.py:1(<module>)
#         2    0.011    0.005    0.011    0.005 {built-in method _winapi.CreateProcess}
#         3    0.000    0.000    0.011    0.004 helpers.py:1(<module>)
#       406    0.003    0.000    0.011    0.000 _compiler.py:509(_compile_info)
#      1093    0.006    0.000    0.011    0.000 functools.py:35(update_wrapper)
#       287    0.001    0.000    0.011    0.000 overrides.py:142(decorator)
#      7695    0.008    0.000    0.010    0.000 <frozen importlib._bootstrap_external>:119(<listcomp>)
#         1    0.000    0.000    0.010    0.010 prefilter.py:1(<module>)
#        36    0.000    0.000    0.010    0.000 font_manager.py:1293(findfont)
#         8    0.000    0.000    0.010    0.001 ticker.py:452(__init__)
#       116    0.001    0.000    0.010    0.000 text.py:157(_reset_visual_defaults)
#         8    0.000    0.000    0.010    0.001 ticker.py:573(set_useMathText)
#         2    0.000    0.000    0.010    0.005 events.py:1(<module>)
#         1    0.000    0.000    0.010    0.010 backend_bases.py:2340(start_event_loop)
#         1    0.010    0.010    0.010    0.010 {built-in method time.sleep}
#         1    0.000    0.000    0.010    0.010 scale.py:1(<module>)
# 3349/1050    0.008    0.000    0.010    0.000 _parser.py:172(getwidth)
#         1    0.000    0.000    0.010    0.010 traitlets.py:1(<module>)
#        14    0.000    0.000    0.010    0.001 __init__.py:821(lookup)
#        14    0.001    0.000    0.010    0.001 __init__.py:827(__init__)
#        38    0.001    0.000    0.010    0.000 typing.py:2858(__new__)
#       106    0.001    0.000    0.010    0.000 patches.py:800(get_patch_transform)
#       766    0.007    0.000    0.009    0.000 _compiler.py:241(_optimize_charset)
#         1    0.000    0.000    0.009    0.009 ssl.py:1(<module>)
#        20    0.000    0.000    0.009    0.000 _functools.py:75(wrapper)
#        12    0.000    0.000    0.009    0.001 axis.py:1617(_copy_tick_props)
#         1    0.000    0.000    0.009    0.009 terminal256.py:1(<module>)
#         1    0.000    0.000    0.009    0.009 __init__.py:346(__getattr__)
#         1    0.000    0.000    0.009    0.009 __init__.py:43(_load_lexers)
#      7241    0.009    0.000    0.009    0.000 {method 'reshape' of 'numpy.ndarray' objects}
#         1    0.000    0.000    0.009    0.009 klass.py:1(<module>)
#         1    0.000    0.000    0.009    0.009 subprocess.py:1165(communicate)
#        19    0.000    0.000    0.009    0.000 rcsetup.py:814(validate_cycler)
#      1037    0.004    0.000    0.009    0.000 typing.py:168(_type_check)
#         9    0.000    0.000    0.009    0.001 dataclasses.py:1219(wrap)
#         1    0.000    0.000    0.009    0.009 controls.py:1(<module>)
#        24    0.000    0.000    0.009    0.000 axis.py:957(set_tick_params)
#         1    0.000    0.000    0.009    0.009 _methods.py:1(<module>)
#         9    0.001    0.000    0.009    0.001 dataclasses.py:884(_process_class)
#         1    0.000    0.000    0.009    0.009 _misc.py:1(<module>)
#         2    0.000    0.000    0.009    0.004 html.py:1(<module>)
#         2    0.000    0.000    0.009    0.004 _matfuncs.py:1(<module>)
#         1    0.000    0.000    0.009    0.009 _svds.py:1(<module>)
#         1    0.002    0.002    0.009    0.009 font_manager.py:1453(_findfont_cached)
#         1    0.000    0.000    0.009    0.009 pdb.py:1(<module>)
#         2    0.000    0.000    0.009    0.004 axis.py:2449(_update_label_position)
#         1    0.000    0.000    0.009    0.009 shutil.py:1(<module>)
#        96    0.000    0.000    0.009    0.000 text.py:65(_get_text_metrics_with_cache)
#         1    0.000    0.000    0.009    0.009 _dtype_like.py:1(<module>)
#         4    0.000    0.000    0.009    0.002 axis.py:2234(_get_tick_boxes_siblings)
#        48    0.000    0.000    0.009    0.000 __init__.py:1403(_add_data_doc)
#         2    0.000    0.000    0.009    0.004 formatters.py:1(<module>)
#         2    0.000    0.000    0.009    0.004 dialogs.py:1(<module>)
#        41    0.000    0.000    0.008    0.000 typing.py:2839(_make_nmtuple)
#         1    0.000    0.000    0.008    0.008 ExifTags.py:1(<module>)
#        36    0.000    0.000    0.008    0.000 lines.py:1338(update_from)
#         1    0.000    0.000    0.008    0.008 windows_events.py:1(<module>)
#      6222    0.004    0.000    0.008    0.000 __init__.py:778(__getitem__)
#      1467    0.003    0.000    0.008    0.000 copy.py:66(copy)
#         1    0.000    0.000    0.008    0.008 legend.py:1(<module>)
#      2985    0.004    0.000    0.008    0.000 {built-in method builtins.max}
#     17327    0.008    0.000    0.008    0.000 _parser.py:231(__next)
#       122    0.000    0.000    0.008    0.000 <frozen importlib._bootstrap_external>:164(_path_isdir)
#         1    0.000    0.000    0.008    0.008 execution.py:1(<module>)
#         1    0.000    0.000    0.008    0.008 collections.py:1014(draw)
#         1    0.000    0.000    0.008    0.008 socket.py:1(<module>)
#         1    0.000    0.000    0.008    0.008 common.py:8(pyparsing_common)
#      1018    0.004    0.000    0.008    0.000 enum.py:364(__setitem__)
#         1    0.000    0.000    0.008    0.008 collections.py:352(draw)
#         8    0.000    0.000    0.008    0.001 _base.py:3273(grid)
#         1    0.000    0.000    0.008    0.008 key_processor.py:1(<module>)
#        16    0.000    0.000    0.008    0.000 axis.py:1707(grid)
#         1    0.000    0.000    0.008    0.008 python.py:1(<module>)
#       993    0.004    0.000    0.008    0.000 <frozen importlib._bootstrap_external>:642(_classify_pyc)
#     10082    0.008    0.000    0.008    0.000 {method 'split' of 'str' objects}
#         1    0.000    0.000    0.008    0.008 generator.py:1(<module>)
#   705/689    0.001    0.000    0.008    0.000 contextlib.py:132(__enter__)
#        58    0.000    0.000    0.008    0.000 typing.py:1367(__or__)
#         1    0.000    0.000    0.008    0.008 _secondary_axes.py:1(<module>)
#       147    0.001    0.000    0.008    0.000 __init__.py:945(_normalized_name)
#   2385/37    0.004    0.000    0.008    0.000 copy.py:128(deepcopy)
#         1    0.000    0.000    0.008    0.008 _svdp.py:1(<module>)
#     33455    0.007    0.000    0.007    0.000 {method 'endswith' of 'str' objects}
#         7    0.000    0.000    0.007    0.001 version.py:1(<module>)
#    154/37    0.001    0.000    0.007    0.000 copy.py:227(_deepcopy_dict)
#       292    0.001    0.000    0.007    0.000 <frozen abc>:105(__new__)
#         2    0.000    0.000    0.007    0.004 _aliases.py:1(<module>)
#         1    0.000    0.000    0.007    0.007 my_getattr_static.py:1(<module>)
#      1183    0.004    0.000    0.007    0.000 <frozen importlib._bootstrap_external>:172(_path_isabs)
#        11    0.000    0.000    0.007    0.001 argparse.py:2564(format_help)
#         1    0.000    0.000    0.007    0.007 ticker.py:1(<module>)
#        12    0.000    0.000    0.007    0.001 core.py:1145(parse_string)
#      3988    0.004    0.000    0.007    0.000 typing.py:1290(__setattr__)
#       746    0.002    0.000    0.007    0.000 <frozen importlib._bootstrap>:216(_lock_unlock_module)
#         1    0.000    0.000    0.007    0.007 table.py:1(<module>)
#         1    0.000    0.000    0.007    0.007 tz.py:1(<module>)
#         1    0.000    0.000    0.007    0.007 names.py:1(<module>)
#         1    0.000    0.000    0.007    0.007 mathtext.py:1(<module>)
#         2    0.000    0.000    0.007    0.003 abc.py:1(<module>)
#         1    0.000    0.000    0.007    0.007 cbook.py:1(<module>)
#         1    0.000    0.000    0.007    0.007 artist.py:1(<module>)
#        64    0.000    0.000    0.007    0.000 deprecation.py:414(make_keyword_only)
#         2    0.000    0.000    0.007    0.003 _basic.py:1(<module>)
#       134    0.001    0.000    0.007    0.000 typing.py:1556(__getitem__)
#         1    0.000    0.000    0.007    0.007 format.py:1(<module>)
#         1    0.006    0.006    0.007    0.007 {built-in method matplotlib.backends._backend_agg.draw_path_collection}
#        50    0.001    0.000    0.007    0.000 lines.py:744(draw)
#         9    0.000    0.000    0.007    0.001 dataclasses.py:1202(dataclass)
#         1    0.000    0.000    0.007    0.007 cm.py:32(_gen_cmap_registry)
#         1    0.000    0.000    0.007    0.007 numerictypes.py:1(<module>)
#         1    0.000    0.000    0.007    0.007 font_manager.py:1625(_load_fontmanager)
#       147    0.000    0.000    0.007    0.000 __init__.py:400(_from_text_for)
#      1870    0.006    0.000    0.007    0.000 <frozen importlib._bootstrap>:100(acquire)
#         5    0.000    0.000    0.006    0.001 exceptions.py:1(<module>)
#       899    0.002    0.000    0.006    0.000 copy.py:259(_reconstruct)
#        11    0.000    0.000    0.006    0.001 argparse.py:285(format_help)
#      3402    0.001    0.000    0.006    0.000 <frozen abc>:117(__instancecheck__)
#     33/11    0.000    0.000    0.006    0.001 argparse.py:212(format_help)
#      1107    0.002    0.000    0.006    0.000 <frozen importlib._bootstrap>:71(__init__)
#     33/11    0.000    0.000    0.006    0.001 argparse.py:217(<listcomp>)
#         3    0.000    0.000    0.006    0.002 patches.py:2293(__init_subclass__)
#         6    0.000    0.000    0.006    0.001 patches.py:2335(pprint_styles)
#         1    0.000    0.000    0.006    0.006 pickle.py:1(<module>)
#        13    0.000    0.000    0.006    0.000 rcsetup.py:426(validate_font_properties)
#        10    0.000    0.000    0.006    0.001 _fontconfig_pattern.py:77(parse_fontconfig_pattern)
#         1    0.000    0.000    0.006    0.006 backend_tools.py:1(<module>)
#         1    0.000    0.000    0.006    0.006 diff.py:1(<module>)
#      1124    0.002    0.000    0.006    0.000 <frozen importlib._bootstrap>:173(__exit__)
#         1    0.000    0.000    0.006    0.006 grammar_parser.py:1(<module>)
#         2    0.000    0.000    0.006    0.003 tree.py:1(<module>)
#         2    0.000    0.000    0.006    0.003 registry.py:1(<module>)
#    306/12    0.001    0.000    0.006    0.000 core.py:806(_parseNoCache)
#         1    0.000    0.000    0.006    0.006 _utils_impl.py:1(<module>)
#      1870    0.005    0.000    0.006    0.000 <frozen importlib._bootstrap>:125(release)
#     72/12    0.000    0.000    0.006    0.000 core.py:4123(parseImpl)
#         2    0.000    0.000    0.006    0.003 registry.py:142(backward_compatible_entry_points)
#         1    0.000    0.000    0.006    0.006 vi.py:1(<module>)
#         1    0.000    0.000    0.006    0.006 key_bindings.py:1(<module>)
#       331    0.001    0.000    0.006    0.000 pathlib.py:484(_parse_args)
#       368    0.000    0.000    0.006    0.000 __init__.py:402(<genexpr>)
#         1    0.000    0.000    0.006    0.006 run_in_terminal.py:1(<module>)
#         2    0.000    0.000    0.006    0.003 __init__.py:1001(version)
#         6    0.000    0.000    0.006    0.001 patches.py:2339(<listcomp>)
#         1    0.000    0.000    0.006    0.006 font_manager.py:1030(json_load)
#        19    0.003    0.000    0.006    0.000 enum.py:1657(convert_class)
#      7605    0.006    0.000    0.006    0.000 {method 'expandtabs' of 'str' objects}
#         1    0.000    0.000    0.006    0.006 texmanager.py:1(<module>)
#         1    0.000    0.000    0.006    0.006 _csr.py:1(<module>)
#       639    0.000    0.000    0.006    0.000 _parser.py:94(closegroup)
#         2    0.000    0.000    0.005    0.003 axis.py:2676(_update_label_position)
#         1    0.000    0.000    0.005    0.005 layout_engine.py:1(<module>)
#         1    0.000    0.000    0.005    0.005 __init__.py:274(load)
#       102    0.000    0.000    0.005    0.000 text.py:194(update)
#      1436    0.001    0.000    0.005    0.000 artist.py:414(pchanged)
#         2    0.000    0.000    0.005    0.003 path.py:1(<module>)
#       252    0.001    0.000    0.005    0.000 overrides.py:83(verify_matching_signatures)
#      3402    0.001    0.000    0.005    0.000 {built-in method _abc._abc_instancecheck}
# 7343/6602    0.003    0.000    0.005    0.000 artist.py:315(stale)
#         1    0.000    0.000    0.005    0.005 _mathtext.py:1(<module>)
#         1    0.000    0.000    0.005    0.005 syntax_tree.py:1(<module>)
#      9366    0.004    0.000    0.005    0.000 {built-in method builtins.setattr}
#        12    0.000    0.000    0.005    0.000 text.py:73(_get_text_metrics_with_cache_impl)
#         1    0.000    0.000    0.005    0.005 spines.py:1(<module>)
#        12    0.000    0.000    0.005    0.000 backend_agg.py:206(get_text_width_height_descent)
#       484    0.003    0.000    0.005    0.000 cbook.py:1742(normalize_kwargs)
#     27692    0.005    0.000    0.005    0.000 {method 'get' of 'dict' objects}
#       368    0.000    0.000    0.005    0.000 __init__.py:406(<genexpr>)
#      2979    0.004    0.000    0.005    0.000 <frozen importlib._bootstrap_external>:84(_unpack_uint32)
#       174    0.000    0.000    0.005    0.000 typing.py:1565(copy_with)
#         1    0.000    0.000    0.005    0.005 lapack.py:1(<module>)
#        58    0.001    0.000    0.005    0.000 lines.py:672(recache)
#     27489    0.005    0.000    0.005    0.000 {method 'rstrip' of 'str' objects}
#         1    0.000    0.000    0.005    0.005 ImagePalette.py:1(<module>)
#         8    0.000    0.000    0.005    0.001 core.py:5779(__init__)
#       530    0.001    0.000    0.005    0.000 typing.py:1251(__init__)
#         1    0.000    0.000    0.005    0.005 _array_like.py:1(<module>)
#       823    0.001    0.000    0.005    0.000 __init__.py:178(sub)
#       562    0.002    0.000    0.005    0.000 typing.py:245(_collect_parameters)
#       2/1    0.000    0.000    0.005    0.005 deprecation.py:442(wrapper)
#         1    0.000    0.000    0.005    0.005 pyplot.py:3919(scatter)
#         1    0.000    0.000    0.005    0.005 version.py:157(Version)
#  2267/493    0.001    0.000    0.005    0.000 <frozen abc>:121(__subclasscheck__)
#         1    0.000    0.000    0.005    0.005 parse.py:1(<module>)
#         4    0.000    0.000    0.005    0.001 spines.py:142(get_window_extent)
#       167    0.000    0.000    0.005    0.000 pathlib.py:868(__new__)
#         1    0.000    0.000    0.005    0.005 __init__.py:299(loads)
#        60    0.000    0.000    0.005    0.000 _internal.py:25(inner)
#      28/7    0.000    0.000    0.005    0.001 core.py:4658(leave_whitespace)
#         1    0.000    0.000    0.005    0.005 decoder.py:332(decode)
#        16    0.000    0.000    0.005    0.000 backend_agg.py:185(draw_text)
#         1    0.000    0.000    0.005    0.005 arpack.py:1(<module>)
#         1    0.001    0.001    0.005    0.005 decoder.py:343(raw_decode)
#         1    0.000    0.000    0.005    0.005 __init__.py:1518(inner)
#         1    0.000    0.000    0.005    0.005 transforms.py:1(<module>)
#       172    0.000    0.000    0.005    0.000 pathlib.py:504(_from_parts)
#       116    0.000    0.000    0.005    0.000 text.py:1316(set_fontproperties)
# 1468/1462    0.003    0.000    0.005    0.000 cbook.py:348(process)
#  2267/493    0.004    0.000    0.005    0.000 {built-in method _abc._abc_subclasscheck}
#         1    0.000    0.000    0.005    0.005 sys_path.py:1(<module>)
#         1    0.000    0.000    0.005    0.005 magic_arguments.py:1(<module>)
#        33    0.000    0.000    0.005    0.000 dataclasses.py:413(_create_fn)
#      2225    0.005    0.000    0.005    0.000 {built-in method _thread.allocate_lock}
#      5958    0.003    0.000    0.005    0.000 <frozen importlib._bootstrap_external>:134(<genexpr>)
#         2    0.000    0.000    0.005    0.002 subprocess.py:1(<module>)
#         1    0.000    0.000    0.005    0.005 configurable.py:1(<module>)
#       283    0.002    0.000    0.005    0.000 artist.py:179(__init__)
#       993    0.002    0.000    0.005    0.000 <frozen importlib._bootstrap_external>:675(_validate_timestamp_pyc)
#         1    0.000    0.000    0.005    0.005 tempfile.py:1(<module>)
#       113    0.000    0.000    0.005    0.000 rcsetup.py:99(f)
#      6548    0.003    0.000    0.005    0.000 __init__.py:698(_get)
#         1    0.000    0.000    0.004    0.004 staggered.py:1(<module>)
#       334    0.003    0.000    0.004    0.000 pathlib.py:56(parse_parts)
#       445    0.001    0.000    0.004    0.000 core.py:519(copy)
#        62    0.000    0.000    0.004    0.000 __init__.py:866(_open_file_or_url)
#       368    0.000    0.000    0.004    0.000 __init__.py:101(<genexpr>)
#        12    0.000    0.000    0.004    0.000 enum.py:890(_convert_)
#        10    0.000    0.000    0.004    0.000 util.py:372(_inner)
#         1    0.000    0.000    0.004    0.004 keys.py:1(<module>)
#        39    0.000    0.000    0.004    0.000 colors.py:1080(from_list)
#         1    0.000    0.000    0.004    0.004 platform.py:1(<module>)
#      4709    0.003    0.000    0.004    0.000 typing.py:1238(_is_dunder)
#      1695    0.004    0.000    0.004    0.000 fromnumeric.py:70(<dictcomp>)
#         1    0.000    0.000    0.004    0.004 capi_maps.py:1(<module>)
#         1    0.000    0.000    0.004    0.004 __init__.py:629(version)
#         1    0.000    0.000    0.004    0.004 __init__.py:602(metadata)
#         1    0.000    0.000    0.004    0.004 guarded_eval.py:1(<module>)
#         1    0.000    0.000    0.004    0.004 _axes.py:4746(scatter)
#         1    0.000    0.000    0.004    0.004 dbapi2.py:1(<module>)
#         1    0.000    0.000    0.004    0.004 charset.py:1(<module>)
#       553    0.001    0.000    0.004    0.000 _inspect.py:96(getargspec)
#       301    0.004    0.000    0.004    0.000 sph.py:97(getPressure)
#        28    0.004    0.000    0.004    0.000 {built-in method matplotlib.ft2font.set_text}
#        28    0.000    0.000    0.004    0.000 backend_agg.py:248(_prepare_font)
#         1    0.000    0.000    0.004    0.004 keywords.py:1(<module>)
#      8404    0.004    0.000    0.004    0.000 <frozen importlib._bootstrap>:244(_verbose_message)
#      6608    0.003    0.000    0.004    0.000 _parser.py:170(append)
#        22    0.000    0.000    0.004    0.000 core.py:5062(parseImpl)
#      59/7    0.000    0.000    0.004    0.001 core.py:3880(leave_whitespace)
#         1    0.000    0.000    0.004    0.004 fractions.py:1(<module>)
#        64    0.000    0.000    0.004    0.000 util.py:361(replaced_by_pep8)
#         1    0.000    0.000    0.004    0.004 arguments.py:1(<module>)
#        12    0.000    0.000    0.004    0.000 ticker.py:2226(__call__)
#      1103    0.001    0.000    0.004    0.000 <frozen importlib._bootstrap>:748(find_spec)
#         7    0.000    0.000    0.004    0.001 enum.py:838(_create_)
#   705/689    0.001    0.000    0.004    0.000 contextlib.py:141(__exit__)
#       147    0.000    0.000    0.004    0.000 __init__.py:795(joinpath)
#       812    0.002    0.000    0.004    0.000 enum.py:1515(__and__)
#       433    0.001    0.000    0.004    0.000 font_manager.py:989(_json_decode)
#         1    0.000    0.000    0.004    0.004 basic.py:70(BasicMagics)
#      2703    0.002    0.000    0.004    0.000 cbook.py:468(_strip_comment)
#       642    0.000    0.000    0.004    0.000 __init__.py:163(match)
#         1    0.000    0.000    0.004    0.004 lexer.py:1(<module>)
#    129/61    0.000    0.000    0.004    0.000 core.py:3972(copy)
#         1    0.000    0.000    0.004    0.004 docstrings.py:1(<module>)
#       102    0.000    0.000    0.004    0.000 artist.py:1215(update)
#       891    0.003    0.000    0.004    0.000 inspect.py:735(unwrap)
#       272    0.000    0.000    0.004    0.000 font_manager.py:961(copy)
#         1    0.000    0.000    0.004    0.004 hashlib.py:1(<module>)
#       303    0.003    0.000    0.004    0.000 shape_base.py:22(atleast_1d)
#        36    0.000    0.000    0.004    0.000 argparse.py:513(_format_action)
#        12    0.000    0.000    0.004    0.000 ticker.py:2230(tick_values)
#        12    0.000    0.000    0.004    0.000 axis.py:1538(get_minorticklocs)
#         1    0.000    0.000    0.004    0.004 pydoc.py:1(<module>)
#       356    0.001    0.000    0.004    0.000 inspect.py:786(_finddoc)
#         1    0.000    0.000    0.004    0.004 minidom.py:1(<module>)
#       679    0.000    0.000    0.004    0.000 typing.py:689(<genexpr>)
#         1    0.000    0.000    0.004    0.004 dates.py:1(<module>)
#        43    0.000    0.000    0.004    0.000 typing.py:697(Optional)
#        91    0.001    0.000    0.004    0.000 traitlets.py:954(__new__)
#         3    0.000    0.000    0.004    0.001 _common.py:1(<module>)
#        37    0.000    0.000    0.004    0.000 rcsetup.py:118(<listcomp>)
#         1    0.000    0.000    0.004    0.004 units.py:1(<module>)
#       261    0.000    0.000    0.004    0.000 rcsetup.py:304(validate_color_for_prop_cycle)
#     38/18    0.000    0.000    0.004    0.000 core.py:4641(parseImpl)
#        42    0.000    0.000    0.004    0.000 lines.py:1035(get_path)
#         1    0.000    0.000    0.004    0.004 __init__.py:32(message_from_string)
#         1    0.000    0.000    0.003    0.003 _testutils.py:1(<module>)
#         1    0.000    0.000    0.003    0.003 formatter.py:1(<module>)
#         2    0.000    0.000    0.003    0.002 completion.py:1(<module>)
#       128    0.000    0.000    0.003    0.000 font_manager.py:556(wrapper)
#        19    0.000    0.000    0.003    0.000 rcsetup.py:677(cycler)
#         1    0.000    0.000    0.003    0.003 profiledir.py:1(<module>)
#         1    0.000    0.000    0.003    0.003 handlers.py:1(<module>)
#       208    0.003    0.000    0.003    0.000 {built-in method builtins.compile}
#         1    0.000    0.000    0.003    0.003 wcwidth.py:1(<module>)
#      7184    0.002    0.000    0.003    0.000 _parser.py:247(match)
#      1312    0.001    0.000    0.003    0.000 _compiler.py:396(_simple)
#     14/12    0.000    0.000    0.003    0.000 axis.py:1206(_set_lim)
#         1    0.000    0.000    0.003    0.003 polynomial.py:1(<module>)
#       158    0.001    0.000    0.003    0.000 transforms.py:804(from_extents)
#        12    0.001    0.000    0.003    0.000 ticker.py:2157(_raw_ticks)
#     26/14    0.000    0.000    0.003    0.000 core.py:4371(parseImpl)
#        24    0.001    0.000    0.003    0.000 util.py:209(_collapse_string_to_ranges)
#         2    0.000    0.000    0.003    0.002 linalg.py:1(<module>)
#         1    0.000    0.000    0.003    0.003 _tripcolor.py:1(<module>)
#         1    0.000    0.000    0.003    0.003 tokenize.py:1(<module>)
#        67    0.000    0.000    0.003    0.000 <string>:2(__init__)
#      1280    0.002    0.000    0.003    0.000 cbook.py:2010(_setattr_cm)
#      1192    0.001    0.000    0.003    0.000 typing.py:159(_type_convert)
#         1    0.000    0.000    0.003    0.003 locks.py:1(<module>)
#     34000    0.003    0.000    0.003    0.000 {built-in method builtins.callable}
#         1    0.000    0.000    0.003    0.003 win.py:1(<module>)
#         1    0.000    0.000    0.003    0.003 _function_base_impl.py:1(<module>)
#        24    0.000    0.000    0.003    0.000 axis.py:302(_apply_params)
#        67    0.000    0.000    0.003    0.000 __init__.py:56(__post_init__)
#         1    0.000    0.000    0.003    0.003 sslproto.py:1(<module>)
#      4384    0.002    0.000    0.003    0.000 <frozen importlib._bootstrap>:1030(__exit__)
# ...
#         1    0.000    0.000    0.000    0.000 errors.py:854(_ArgumentRule)
#         1    0.000    0.000    0.000    0.000 errors.py:880(_NonlocalModuleLevelRule)
#         1    0.000    0.000    0.000    0.000 errors.py:1031(_CheckAssignmentRule)
#         1    0.000    0.000    0.000    0.000 errors.py:1151(_CompForRule)
#         1    0.000    0.000    0.000    0.000 file_io.py:78(FileIO)
#         1    0.000    0.000    0.000    0.000 value.py:414(CompiledValueName)
#         1    0.000    0.000    0.000    0.000 value.py:600(_normalize_create_args)
#         1    0.000    0.000    0.000    0.000 analysis.py:72(Warning)
#         1    0.000    0.000    0.000    0.000 filters.py:349(_AttributeOverwriteMixin)
#         1    0.000    0.000    0.000    0.000 names.py:620(SubModuleName)
#         1    0.000    0.000    0.000    0.000 arguments.py:135(AbstractArguments)
#         1    0.000    0.000    0.000    0.000 context.py:395(CompiledContext)
#         1    0.000    0.000    0.000    0.000 dynamic_arrays.py:197(ListModification)
#         1    0.000    0.000    0.000    0.000 typing.py:403(NewTypeFunction)
#         1    0.000    0.000    0.000    0.000 exceptions.py:5(InternalError)
#         1    0.000    0.000    0.000    0.000 exceptions.py:21(RefactoringError)
#         1    0.000    0.000    0.000    0.000 environment.py:132(SameEnvironment)
#         1    0.000    0.000    0.000    0.000 stdlib.py:872(tree_name_to_values)
#         1    0.000    0.000    0.000    0.000 stdlib.py:628(DataclassSignature)
#         1    0.000    0.000    0.000    0.000 pytest.py:21(execute)
#         1    0.000    0.000    0.000    0.000 django.py:215(get_metaclass_signatures)
#         1    0.000    0.000    0.000    0.000 code.py:45(MacroToEdit)
#         1    0.000    0.000    0.000    0.000 client.py:1463(HTTPException)
#         1    0.000    0.000    0.000    0.000 client.py:1482(UnimplementedFileMode)
#         1    0.000    0.000    0.000    0.000 client.py:1502(CannotSendRequest)
#         1    0.000    0.000    0.000    0.000 client.py:1523(RemoteDisconnected)
#         1    0.000    0.000    0.000    0.000 {method 'clear' of 'collections.OrderedDict' objects}
#         2    0.000    0.000    0.000    0.000 contextlib.py:543(__enter__)
#         1    0.000    0.000    0.000    0.000 contextlib.py:757(__exit__)
#         2    0.000    0.000    0.000    0.000 multiarray.py:988(ravel_multi_index)
#         1    0.000    0.000    0.000    0.000 exceptions.py:59(ModuleDeprecationWarning)
#         1    0.000    0.000    0.000    0.000 subprocess.py:695(_use_posix_spawn)
#         1    0.000    0.000    0.000    0.000 exceptions.py:87(RankWarning)
#         1    0.000    0.000    0.000    0.000 exceptions.py:97(TooHardError)
#         1    0.000    0.000    0.000    0.000 pickle.py:77(PicklingError)
#         1    0.000    0.000    0.000    0.000 __init__.py:165(c_short)
#         1    0.000    0.000    0.000    0.000 __init__.py:169(c_ushort)
#         1    0.000    0.000    0.000    0.000 __init__.py:235(c_char)
#         1    0.000    0.000    0.000    0.000 __init__.py:240(c_char_p)
#         1    0.000    0.000    0.000    0.000 __init__.py:246(c_void_p)
#         1    0.000    0.000    0.000    0.000 __init__.py:408(WinDLL)
#         1    0.000    0.000    0.000    0.000 _endian.py:35(_swapped_union_meta)
#         1    0.000    0.000    0.000    0.000 _iotools.py:422(ConverterError)
#         1    0.000    0.000    0.000    0.000 _iotools.py:430(ConverterLockError)
#         1    0.000    0.000    0.000    0.000 _iotools.py:438(ConversionWarning)
#         1    0.000    0.000    0.000    0.000 threading.py:832(<listcomp>)
#         1    0.000    0.000    0.000    0.000 threading.py:798(BrokenBarrierError)
#         1    0.000    0.000    0.000    0.000 subprocess.py:1089(__enter__)
#         1    0.000    0.000    0.000    0.000 shutil.py:67(SpecialFileError)
#         1    0.000    0.000    0.000    0.000 shutil.py:77(RegistryError)
#         1    0.000    0.000    0.000    0.000 shutil.py:81(_GiveupOnFastCopy)
#         1    0.000    0.000    0.000    0.000 version.py:308(post)
#         1    0.000    0.000    0.000    0.000 version.py:319(dev)
#         1    0.000    0.000    0.000    0.000 registry.py:153(<listcomp>)
#         1    0.000    0.000    0.000    0.000 rcsetup.py:375(validate_fontsize_None)
#         1    0.000    0.000    0.000    0.000 rcsetup.py:889(_ignorecase)
#         1    0.000    0.000    0.000    0.000 Image.py:77(DecompressionBombWarning)
#         1    0.000    0.000    0.000    0.000 exceptions.py:292(ParseSyntaxException)
#         1    0.000    0.000    0.000    0.000 results.py:19(<genexpr>)
#         1    0.000    0.000    0.000    0.000 core.py:146(MAError)
#         1    0.000    0.000    0.000    0.000 core.py:154(MaskError)
#         1    0.000    0.000    0.000    0.000 extras.py:339(_fromnxfunction_allargs)
#         1    0.000    0.000    0.000    0.000 zipfile.py:47(LargeZipFile)
#         1    0.000    0.000    0.000    0.000 calendar.py:162(setfirstweekday)
#         1    0.000    0.000    0.000    0.000 errors.py:28(CharsetError)
#         1    0.000    0.000    0.000    0.000 errors.py:41(NoBoundaryInMultipartDefect)
#         1    0.000    0.000    0.000    0.000 errors.py:44(StartBoundaryNotFoundDefect)
#         1    0.000    0.000    0.000    0.000 errors.py:47(CloseBoundaryNotFoundDefect)
#         1    0.000    0.000    0.000    0.000 errors.py:50(FirstHeaderLineIsContinuationDefect)
#         1    0.000    0.000    0.000    0.000 errors.py:53(MisplacedEnvelopeHeaderDefect)
#         1    0.000    0.000    0.000    0.000 errors.py:56(MissingHeaderBodySeparatorDefect)
#         1    0.000    0.000    0.000    0.000 errors.py:61(MultipartInvariantViolationDefect)
#         1    0.000    0.000    0.000    0.000 errors.py:64(InvalidMultipartContentTransferEncodingDefect)
#         1    0.000    0.000    0.000    0.000 errors.py:67(UndecodableBytesDefect)
#         1    0.000    0.000    0.000    0.000 errors.py:73(InvalidBase64CharactersDefect)
#         1    0.000    0.000    0.000    0.000 errors.py:76(InvalidBase64LengthDefect)
#         1    0.000    0.000    0.000    0.000 hatch.py:67(SouthEastHatch)
#         1    0.000    0.000    0.000    0.000 hatch.py:140(LargeCircles)
#         1    0.000    0.000    0.000    0.000 backend_bases.py:2737(set_window_title)
#         1    0.000    0.000    0.000    0.000 backend_tools.py:622(ConfigureSubplotsBase)
#         1    0.000    0.000    0.000    0.000 patches.py:3539(CurveFilledA)
#         1    0.000    0.000    0.000    0.000 _mathtext.py:966(DejaVuSerifFontConstants)
#         1    0.000    0.000    0.000    0.000 _mathtext.py:970(DejaVuSansFontConstants)
#         1    0.000    0.000    0.000    0.000 __init__.py:14(SubplotBase)
#         1    0.000    0.000    0.000    0.000 _parser.py:1608(UnknownTimezoneWarning)
#         1    0.000    0.000    0.000    0.000 six.py:475(Module_six_moves_urllib_robotparser)
#         1    0.000    0.000    0.000    0.000 __init__.py:11(DeprecatedTzFormatWarning)
#         1    0.000    0.000    0.000    0.000 argparse.py:687(RawTextHelpFormatter)
#         1    0.000    0.000    0.000    0.000 argparse.py:781(ArgumentTypeError)
#         1    0.000    0.000    0.000    0.000 argparse.py:1249(_ExtendAction)
#         1    0.000    0.000    0.000    0.000 case.py:33(_ShouldStop)
#         1    0.000    0.000    0.000    0.000 case.py:38(_UnexpectedSuccess)
#         1    0.000    0.000    0.000    0.000 _base.py:19(SparseFormatWarning)
#         1    0.000    0.000    0.000    0.000 _csr.py:307(csr_array)
#         1    0.000    0.000    0.000    0.000 _csr.py:430(csr_matrix)
#         1    0.000    0.000    0.000    0.000 _csc.py:271(csc_matrix)
#         1    0.000    0.000    0.000    0.000 traitlets.py:512(instance_init)
#         1    0.000    0.000    0.000    0.000 traitlets.py:2208(ForwardDeclaredInstance)
#         1    0.000    0.000    0.000    0.000 socketserver.py:716(ThreadingUDPServer)
#         1    0.000    0.000    0.000    0.000 socketserver.py:717(ThreadingTCPServer)
#         1    0.000    0.000    0.000    0.000 configurable.py:36(MultipleInstanceError)
#         1    0.000    0.000    0.000    0.000 loader.py:29(ConfigLoaderError)
#         1    0.000    0.000    0.000    0.000 loader.py:37(ArgumentError)
#         1    0.000    0.000    0.000    0.000 util.py:34(OptionError)
#         1    0.000    0.000    0.000    0.000 util.py:265(Future)
#         1    0.000    0.000    0.000    0.000 _sysinfo.py:1(<module>)
#         1    0.000    0.000    0.000    0.000 error.py:48(StdinNotImplementedError)
#         1    0.000    0.000    0.000    0.000 lexer.py:328(include)
#         1    0.000    0.000    0.000    0.000 lexer.py:335(_inherit)
#         1    0.000    0.000    0.000    0.000 lexer.py:470(default)
#         1    0.000    0.000    0.000    0.000 alias.py:117(InvalidAliasError)
#         1    0.000    0.000    0.000    0.000 builtin_trap.py:16(__HideBuiltin)
#         1    0.000    0.000    0.000    0.000 events.py:709(_RunningLoop)
#         1    0.000    0.000    0.000    0.000 windows_events.py:305(_WindowsSelectorEventLoop)
#         1    0.000    0.000    0.000    0.000 auto_suggest.py:111(DummyAutoSuggest)
#         1    0.000    0.000    0.000    0.000 __init__.py:79(DomstringSizeErr)
#         1    0.000    0.000    0.000    0.000 __init__.py:82(HierarchyRequestErr)
#         1    0.000    0.000    0.000    0.000 __init__.py:85(WrongDocumentErr)
#         1    0.000    0.000    0.000    0.000 __init__.py:91(NoDataAllowedErr)
#         1    0.000    0.000    0.000    0.000 __init__.py:94(NoModificationAllowedErr)
#         1    0.000    0.000    0.000    0.000 __init__.py:97(NotFoundErr)
#         1    0.000    0.000    0.000    0.000 __init__.py:100(NotSupportedErr)
#         1    0.000    0.000    0.000    0.000 __init__.py:106(InvalidStateErr)
#         1    0.000    0.000    0.000    0.000 __init__.py:109(SyntaxErr)
#         1    0.000    0.000    0.000    0.000 __init__.py:118(InvalidAccessErr)
#         1    0.000    0.000    0.000    0.000 __init__.py:121(ValidationErr)
#         1    0.000    0.000    0.000    0.000 layout.py:392(InvalidLayoutError)
#         1    0.000    0.000    0.000    0.000 toolbars.py:331(CompletionsToolbar)
#         1    0.000    0.000    0.000    0.000 guarded_eval.py:340(GuardRejection)
#         1    0.000    0.000    0.000    0.000 diff.py:233(_PositionUpdatingFinished)
#         1    0.000    0.000    0.000    0.000 tree.py:685(Flow)
#         1    0.000    0.000    0.000    0.000 errors.py:1205(_DelStmtRule)
#         1    0.000    0.000    0.000    0.000 errors.py:1214(_ExprListRule)
#         1    0.000    0.000    0.000    0.000 errors.py:1230(_NamedExprRule)
#         1    0.000    0.000    0.000    0.000 file_io.py:82(KnownContentFileIO)
#         1    0.000    0.000    0.000    0.000 filters.py:355(LazyAttributeOverwrite)
#         1    0.000    0.000    0.000    0.000 names.py:676(StubModuleName)
#         1    0.000    0.000    0.000    0.000 stub_value.py:101(VersionInfo)
#         1    0.000    0.000    0.000    0.000 arguments.py:34(ParamIssue)
#         1    0.000    0.000    0.000    0.000 iterable.py:242(SetComprehension)
#         1    0.000    0.000    0.000    0.000 iterable.py:516(FakeTuple)
#         1    0.000    0.000    0.000    0.000 iterable.py:520(FakeList)
#         1    0.000    0.000    0.000    0.000 instance.py:396(AnonymousInstance)
#         1    0.000    0.000    0.000    0.000 typing.py:386(Protocol)
#         1    0.000    0.000    0.000    0.000 exceptions.py:14(WrongVersion)
#         1    0.000    0.000    0.000    0.000 pytest.py:96(complete_param_names)
#         1    0.000    0.000    0.000    0.000 django.py:165(get_metaclass_filters)
#         1    0.000    0.000    0.000    0.000 client.py:1468(NotConnected)
#         1    0.000    0.000    0.000    0.000 client.py:1479(UnknownTransferEncoding)
#         1    0.000    0.000    0.000    0.000 client.py:1499(ImproperConnectionState)
#         1    0.000    0.000    0.000    0.000 client.py:1508(ResponseNotReady)
#         1    0.000    0.000    0.000    0.000 {built-in method _thread.get_native_id}
#         1    0.000    0.000    0.000    0.000 _linalg.py:495(_unary_dispatcher)
#         1    0.000    0.000    0.000    0.000 __init__.py:173(c_long)
#         1    0.000    0.000    0.000    0.000 __init__.py:177(c_ulong)
#         1    0.000    0.000    0.000    0.000 __init__.py:194(c_float)
#         1    0.000    0.000    0.000    0.000 __init__.py:198(c_double)
#         1    0.000    0.000    0.000    0.000 __init__.py:212(c_longlong)
#         1    0.000    0.000    0.000    0.000 __init__.py:216(c_ulonglong)
#         1    0.000    0.000    0.000    0.000 __init__.py:223(c_ubyte)
#         1    0.000    0.000    0.000    0.000 __init__.py:230(c_byte)
#         1    0.000    0.000    0.000    0.000 __init__.py:251(c_bool)
#         1    0.000    0.000    0.000    0.000 __init__.py:261(c_wchar)
#         1    0.000    0.000    0.000    0.000 __init__.py:67(_256Bit)
#         1    0.000    0.000    0.000    0.000 __init__.py:70(_128Bit)
#         1    0.000    0.000    0.000    0.000 __init__.py:76(_80Bit)
#         1    0.000    0.000    0.000    0.000 __init__.py:79(_64Bit)
#         1    0.000    0.000    0.000    0.000 __init__.py:82(_32Bit)
#         1    0.000    0.000    0.000    0.000 shutil.py:61(Error)
#         1    0.000    0.000    0.000    0.000 shutil.py:71(ExecError)
#         1    0.000    0.000    0.000    0.000 shutil.py:74(ReadError)
#         1    0.000    0.000    0.000    0.000 Image.py:81(DecompressionBombError)
#         1    0.000    0.000    0.000    0.000 common.py:71(NotSupportedError)
#         1    0.000    0.000    0.000    0.000 transforms.py:2110(frozen)
#         1    0.000    0.000    0.000    0.000 <string>:1(__create_fn__)
#         1    0.000    0.000    0.000    0.000 core.py:864(__init__)
#         1    0.000    0.000    0.000    0.000 errors.py:70(InvalidBase64PaddingDefect)
#         2    0.000    0.000    0.000    0.000 feedparser.py:125(__iter__)
#         1    0.000    0.000    0.000    0.000 backend_bases.py:1866(draw)
#         1    0.000    0.000    0.000    0.000 backend_bases.py:2721(destroy)
#         1    0.000    0.000    0.000    0.000 _base.py:799(get_subplotspec)
#         1    0.000    0.000    0.000    0.000 six.py:239(exec_module)
#         1    0.000    0.000    0.000    0.000 _base.py:23(SparseEfficiencyWarning)
#         1    0.000    0.000    0.000    0.000 loader.py:33(ConfigFileNotFound)
#         1    0.000    0.000    0.000    0.000 ipstruct.py:223(dict)
#         1    0.000    0.000    0.000    0.000 error.py:41(UsageError)
#         1    0.000    0.000    0.000    0.000 lexer.py:411(_This)
#         1    0.000    0.000    0.000    0.000 __init__.py:756(ErrorToken)
#         1    0.000    0.000    0.000    0.000 exceptions.py:21(SendfileNotAvailableError)
#         1    0.000    0.000    0.000    0.000 exceptions.py:61(BrokenBarrierError)
#         1    0.000    0.000    0.000    0.000 __init__.py:103(InuseAttributeErr)
#         1    0.000    0.000    0.000    0.000 __init__.py:115(NamespaceErr)
#         1    0.000    0.000    0.000    0.000 mixed.py:107(MixedModuleContext)
#         1    0.000    0.000    0.000    0.000 filters.py:361(AttributeOverwrite)
#         1    0.000    0.000    0.000    0.000 django.py:175(tree_name_to_values)
#         1    0.000    0.000    0.000    0.000 client.py:1471(InvalidURL)
#         1    0.000    0.000    0.000    0.000 {method '__enter__' of '_thread.lock' objects}
#         1    0.000    0.000    0.000    0.000 {method '__array_wrap__' of 'numpy.ndarray' objects}
#         1    0.000    0.000    0.000    0.000 {built-in method numpy._core._multiarray_umath._set_madvise_hugepage}
#         1    0.000    0.000    0.000    0.000 __init__.py:73(_96Bit)
#         1    0.000    0.000    0.000    0.000 __init__.py:85(_16Bit)
#         1    0.000    0.000    0.000    0.000 __init__.py:88(_8Bit)
#         1    0.000    0.000    0.000    0.000 backend_bases.py:2333(flush_events)
#         1    0.000    0.000    0.000    0.000 {method '__prepare__' of 'type' objects}

# %%
! python -m cProfile -o profile.stats sph.py
# Out:
# Figure(320x400)

# %% [markdown]
# ### snakeviz

# %%
! python -m snakeviz profile.stats --server
# Out:
# ^C

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ## Profiling with memory_profile

# %%
! python -m memory_profiler sph.py
# Out:
# Figure(320x400)

# %%
! python -m mprof run sph.py
# Out:
# mprof.py: Sampling memory every 0.1s
# running new process
# running as a Python program...
# Figure(320x400)

# %%
! python -m mprof plot mprofile_20250123115442.dat
# Out:
# ^C
# Figure(1260x540)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ## Profiling with line_profiler

# %%
! python -m kernprof -l sph_profile.py
# Out:
# Figure(320x400)
# Wrote profile results to sph_profile.py.lprof
# Inspect results with:
# c:\Users\rmare\AppData\Local\Programs\Python\Python311\python.exe -m line_profiler -rmt "sph_profile.py.lprof"

# %%
! python -m line_profiler -rmt "sph_profile.py.lprof"
# Out:
# Timer unit: 1e-06 s
#
# Total time: 0.0054135 s
# File: sph_profile.py
# Function: getPressure at line 96
#
# Line #      Hits         Time  Per Hit   % Time  Line Contents
# ==============================================================
#     96                                           @profile
#     97                                           def getPressure(rho, k, n):
#     98                                           	"""
#     99                                           	Equation of State
#    100                                           	rho   vector of densities
#    101                                           	k     equation of state constant
#    102                                           	n     polytropic index
#    103                                           	P     pressure
#    104                                           	"""
#    105
#    106       301       5209.8     17.3     96.2  	P = k * rho**(1+1/n)
#    107
#    108       301        203.7      0.7      3.8  	return P
#
# Total time: 1.48598 s
# File: sph_profile.py
# Function: getPairwiseSeparations at line 48
#
# Line #      Hits         Time  Per Hit   % Time  Line Contents
# ==============================================================
#     48                                           @profile
#     49                                           def getPairwiseSeparations( ri, rj ):
#     50                                           	"""
#     51                                           	Get pairwise desprations between 2 sets of coordinates
#     52                                           	ri    is an M x 3 matrix of positions
#     53                                           	rj    is an N x 3 matrix of positions
#     54                                           	dx, dy, dz   are M x N matrices of separations
#     55                                           	"""
#     56
#     57       903       2170.4      2.4      0.1  	M = ri.shape[0]
#     58       903       1012.0      1.1      0.1  	N = rj.shape[0]
#     59
#     60                                           	# positions ri = (x,y,z)
#     61       903       6646.6      7.4      0.4  	rix = ri[:,0].reshape((M,1))
#     62       903       1939.6      2.1      0.1  	riy = ri[:,1].reshape((M,1))
#     63       903       1546.9      1.7      0.1  	riz = ri[:,2].reshape((M,1))
#     64
#     65                                           	# other set of points positions rj = (x,y,z)
#     66       903       1717.0      1.9      0.1  	rjx = rj[:,0].reshape((N,1))
#     67       903       1546.6      1.7      0.1  	rjy = rj[:,1].reshape((N,1))
#     68       903       1634.4      1.8      0.1  	rjz = rj[:,2].reshape((N,1))
#     69
#     70                                           	# matrices that store all pairwise particle separations: r_i - r_j
#     71       903     523053.8    579.2     35.2  	dx = rix - rjx.T
#     72       903     464613.6    514.5     31.3  	dy = riy - rjy.T
#     73       903     478667.0    530.1     32.2  	dz = riz - rjz.T
#     74
#     75       903       1432.1      1.6      0.1  	return dx, dy, dz
#
# Total time: 2.77457 s
# File: sph_profile.py
# Function: gradW at line 28
#
# Line #      Hits         Time  Per Hit   % Time  Line Contents
# ==============================================================
#     28                                           @profile
#     29                                           def gradW( x, y, z, h ):
#     30                                           	"""
#     31                                           	Gradient of the Gausssian Smoothing kernel (3D)
#     32                                           	x     is a vector/matrix of x positions
#     33                                           	y     is a vector/matrix of y positions
#     34                                           	z     is a vector/matrix of z positions
#     35                                           	h     is the smoothing length
#     36                                           	wx, wy, wz     is the evaluated gradient
#     37                                           	"""
#     38
#     39       301     976588.2   3244.5     35.2  	r = np.sqrt(x**2 + y**2 + z**2)
#     40
#     41       301    1327771.3   4411.2     47.9  	n = -2 * np.exp( -r**2 / h**2) / h**5 / (np.pi)**(3/2)
#     42       301     159832.9    531.0      5.8  	wx = n * x
#     43       301     154823.9    514.4      5.6  	wy = n * y
#     44       301     154945.5    514.8      5.6  	wz = n * z
#     45
#     46       301        610.3      2.0      0.0  	return wx, wy, wz
#
# Total time: 3.92329 s
# File: sph_profile.py
# Function: W at line 11
#
# Line #      Hits         Time  Per Hit   % Time  Line Contents
# ==============================================================
#     11                                           @profile
#     12                                           def W( x, y, z, h ):
#     13                                           	"""
#     14                                               Gausssian Smoothing kernel (3D)
#     15                                           	x     is a vector/matrix of x positions
#     16                                           	y     is a vector/matrix of y positions
#     17                                           	z     is a vector/matrix of z positions
#     18                                           	h     is the smoothing length
#     19                                           	w     is the evaluated smoothing function
#     20                                           	"""
#     21
#     22       602    1912881.9   3177.5     48.8  	r = np.sqrt(x**2 + y**2 + z**2)
#     23
#     24       602    2008895.6   3337.0     51.2  	w = (1.0 / (h*np.sqrt(np.pi)))**3 * np.exp( -r**2 / h**2)
#     25
#     26       602       1513.0      2.5      0.0  	return w
#
# Total time: 5.55179 s
# File: sph_profile.py
# Function: getDensity at line 77
#
# Line #      Hits         Time  Per Hit   % Time  Line Contents
# ==============================================================
#     77                                           @profile
#     78                                           def getDensity( r, pos, m, h ):
#     79                                           	"""
#     80                                           	Get Density at sampling loctions from SPH particle distribution
#     81                                           	r     is an M x 3 matrix of sampling locations
#     82                                           	pos   is an N x 3 matrix of SPH particle positions
#     83                                           	m     is the particle mass
#     84                                           	h     is the smoothing length
#     85                                           	rho   is M x 1 vector of densities
#     86                                           	"""
#     87
#     88       602       1418.0      2.4      0.0  	M = r.shape[0]
#     89
#     90       602    1005958.3   1671.0     18.1  	dx, dy, dz = getPairwiseSeparations( r, pos );
#     91
#     92       602    4543773.9   7547.8     81.8  	rho = np.sum( m * W(dx, dy, dz, h), 1 ).reshape((M,1))
#     93
#     94       602        637.8      1.1      0.0  	return rho
#
# Total time: 8.03849 s
# File: sph_profile.py
# Function: getAcc at line 110
#
# Line #      Hits         Time  Per Hit   % Time  Line Contents
# ==============================================================
#    110                                           @profile
#    111                                           def getAcc( pos, vel, m, h, k, n, lmbda, nu ):
#    112                                           	"""
#    113                                           	Calculate the acceleration on each SPH particle
#    114                                           	pos   is an N x 3 matrix of positions
#    115                                           	vel   is an N x 3 matrix of velocities
#    116                                           	m     is the particle mass
#    117                                           	h     is the smoothing length
#    118                                           	k     equation of state constant
#    119                                           	n     polytropic index
#    120                                           	lmbda external force constant
#    121                                           	nu    viscosity
#    122                                           	a     is N x 3 matrix of accelerations
#    123                                           	"""
#    124
#    125       301       1329.1      4.4      0.0  	N = pos.shape[0]
#    126
#    127                                           	# Calculate densities at the position of the particles
#    128       301    2892687.0   9610.3     36.0  	rho = getDensity( pos, pos, m, h )
#    129
#    130                                           	# Get the pressures
#    131       301      10416.0     34.6      0.1  	P = getPressure(rho, k, n)
#    132
#    133                                           	# Get pairwise distances and gradients
#    134       301     508056.5   1687.9      6.3  	dx, dy, dz = getPairwiseSeparations( pos, pos )
#    135       301    2844800.0   9451.2     35.4  	dWx, dWy, dWz = gradW( dx, dy, dz, h )
#    136
#    137                                           	# Add Pressure contribution to accelerations
#    138       301     599622.6   1992.1      7.5  	ax = - np.sum( m * ( P/rho**2 + P.T/rho.T**2  ) * dWx, 1).reshape((N,1))
#    139       301     581093.4   1930.5      7.2  	ay = - np.sum( m * ( P/rho**2 + P.T/rho.T**2  ) * dWy, 1).reshape((N,1))
#    140       301     570452.2   1895.2      7.1  	az = - np.sum( m * ( P/rho**2 + P.T/rho.T**2  ) * dWz, 1).reshape((N,1))
#    141
#    142                                           	# pack together the acceleration components
#    143       301      22050.8     73.3      0.3  	a = np.hstack((ax,ay,az))
#    144
#    145                                           	# Add external potential force
#    146       301       4609.0     15.3      0.1  	a -= lmbda * pos
#    147
#    148                                           	# Add viscosity
#    149       301       3162.7     10.5      0.0  	a -= nu * vel
#    150
#    151       301        213.5      0.7      0.0  	return a
#
#   0.01 seconds - sph_profile.py:96 - getPressure
#   1.49 seconds - sph_profile.py:48 - getPairwiseSeparations
#   2.77 seconds - sph_profile.py:28 - gradW
#   3.92 seconds - sph_profile.py:11 - W
#   5.55 seconds - sph_profile.py:77 - getDensity
#   8.04 seconds - sph_profile.py:110 - getAcc
